# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from md04_func import *

# %% [markdown]
# df=pd.DataFrame(md04['data'], columns=md04['header'])
# df['cum']=df.Change.cumsum()
# df.cum.plot(x="Date")
# plt.plot(df.Date, df.cum)
# target=df.mask('Type','ShipNt')
# plt.plot(target.Date, target.cum)

# %% [markdown]
# filelist=[]
# f=open("MD04list.txt","r", encoding="UTF-8")
# list=f.readlines()
# for i in list :
#     document=fileRead(i.rstrip("\n"))
#     md04=parsingDoc(document)
#     PD=pd.DataFrame(md04["data"], columns=md04["header"])
#
#
#
# fig = plt.figure()
# ax= PD['Rec/reqd Qty'].plot(x="Date", kind="bar", title=md04['meta'][0])
# ax2 = ax.twinx()
# ax2.plot(ax.get_xticks(),PD['AvailQty'])

# %% [markdown]
# ## CONSTAT / DICTIONARY FOR PARSING

# %%
category = {
    'ShipNt' :  "Receipt",
    'SchLne' :  "Receipt",    
    'Stock'  :  "Receipt",
    'CStock' : "Reqmt",
    'Ordres' : "Reqmt",    
    'Order'  :  "Reqmt",
    'Deliv.' : "Reqmt",
    'PrdOrd' : "", #normally assigned together with cstock. no need to count
    'OrdRes' : "Reqmt",
    'TrRes.' : "Reqmt",
    'DepReq' : "Reqmt",
    'RelOrd' : "Reqmt",
    'Fr.del' : "Reqmt",
    'SafeSt' : "",
    'StLcSt' : "",
    'PurRqs' : "",
    'IndReq' : ""
}
header=["Partnr","SO_Date","SO_MRP", "SO_NR", "SO_POS","SO_QTY", "PO_DATE","PO_MRP","PO_NR", "PO_POS","PO_QTY" ]
total=[]

# %% [markdown]
# ## FUNCTION

# %%
def kmatParser(df) : 
    MappedResult=[]
    idx=mask(df, "Type", "CStock").index
    CStockReqmt=df.iloc[idx]
    CStockReceipt=df.iloc[idx+1]

    if len(CStockReqmt) != len(CStockReceipt) : 
        print("Please check CStock as rows are not matched")
    
    for i,val in enumerate(CStockReceipt.iterrows()):
        MappedResult.append (CStockReqmt.iloc[i].tolist()[0:6] + (CStockReceipt.iloc[i].tolist()[1:6]))
    
    return MappedResult, df.drop(index=idx+1).drop(index=idx)

# %%
def fehaParser(df) :
    ReceiptQueue=[]
    ReqmtQueue=[]
    MappedResult=[]
    flag=0
    Receipt=[]
    Reqmt=[]

    
    #KMAT PARSER
    MappedResult,df = kmatParser(df)    
    
    
    for index, line in df.iterrows() :    
        print(line)
        if line[6]==0  and line[2]== 'Stock' : continue
        if line[2] == 'Stock' : 
            line[5]=line[6]
        if category[line[2]] == 'Receipt' :        
            ReceiptQueue.append(line)
        if category[line[2]] == 'Reqmt' :
            ReqmtQueue.append(line)
        else :
            continue
            
    #If df only has kmat (CStock, then it return )
    if len(df)<=1 :        
        return MappedResult    
    
    # Else it goes through the below
    else : 
        try :   
            print("DF")
            print(df,"\n")
            print("MappedResult")
            print(MappedResult, "\n\n")
            print("ReceiptQueue")
            print(ReceiptQueue, "\n\n")
            print("ReqmtQueue")
            print(ReqmtQueue, "\n\n")
            Receipt = ReceiptQueue.pop(0)
            Reqmt = ReqmtQueue.pop(0)  

            while True :                 
                print (Receipt[5], Reqmt[5])
                if Receipt[5] + Reqmt[5] == 0 :                    
                    flag=0
                    MappedResult.append([Reqmt[0], Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])    
                    print("DF")
                    print(df,"\n")
                    print("ReceiptQueue")
                    print(ReceiptQueue, "\n")
                    print("ReqmtQueue")
                    print(ReqmtQueue, "\n\n")
                    
                    if len(ReceiptQueue) +  len(ReqmtQueue) <=0 : 
                        return MappedResult                        
                    
                    Receipt=[]; Receipt = ReceiptQueue.pop(0)
                    Reqmt=[]; Reqmt = ReqmtQueue.pop(0)  

                if Receipt[5] + Reqmt[5] > 0 :                           
                    flag=1
                    MappedResult.append([Reqmt[0], Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],  Receipt[1], Receipt[2], Receipt[3], Receipt[4], -Reqmt[5]])    
                    Receipt[5] +=Reqmt[5]            
                    Reqmt = ReqmtQueue.pop(0)  


                if Receipt[5] + Reqmt[5] < 0 :                                
                    flag=-1
                    MappedResult.append([Reqmt[0], Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], -Receipt[5],  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])
                    Reqmt[5] +=Receipt[5]
                    Receipt = ReceiptQueue.pop(0)

            #if no elment for popping.  
        except Exception as e:   

            if flag == -1:
                MappedResult.append([Reqmt[0], Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],'','' ,'' ,'' ,'' ]) 
            elif flag == 1:
                MappedResult.append([Receipt[0], '','','','','',  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])          

            elif flag == 0:
                print("flag 0")
                print("Reqmt : ")
                print(Reqmt,"\n")
                
                print("Receipt : ")
                print(Receipt, "\n")
                
                
                if len(Reqmt) == 0 and len(Receipt)==0 :                     
                    print("both empty")
                elif len(Reqmt) == 0 and len(Receipt)!=0: 
                    #print("Reqmt empty")
                    MappedResult.append([Receipt[0], '','','','','',  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])          
                elif len(Reqmt) !=0 and len(Receipt) ==0 :                
                    #print("Receipt empty")
                    MappedResult.append([Reqmt[0], Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],'','' ,'' ,'' ,'' ]) 

            #print("ReqmtQueue :", len(ReqmtQueue), "ReceiptQueue :", len(ReceiptQueue))
            for Reqmt in ReqmtQueue :
                MappedResult.append([Reqmt[0], Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],'','' ,'' ,'' ,'' ]) 

            for Receipt in ReceiptQueue :
                MappedResult.append([Receipt[0], '','','','','',  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])          
            print ("!!!!!!!!!!!!!!!!!!!!!!!!")
            print (MappedResult)
            print ("!!!!!!!!!!!!!!!!!!!!!!!!")
            return MappedResult

# %% [markdown]
# ## UNIT TEST

# %%
total=[]
filelist=[]
md04=parsingDoc(fileRead("541267_P02"))
PD=pd.DataFrame(md04["data"], columns=md04["header"])   
df=PD.iloc[:,0:7]    
total.append(pd.DataFrame(fehaParser(df), columns=header))
# Out:
# ['541267', '2018.05.28', 'Stock', '', 0, 0, 539]
# ['541267', '2018.05.28', 'SafeSt', 'Safety Stock', 0, -605, -66]
# ['541267', '2017.10.16', 'Deliv.', '1774340092', '000010', -3, -69]
# ['541267', '2018.03.09', 'TrRes.', '2022286597', '00010', -10, -79]
# ['541267', '2018.03.09', 'TrRes.', '2022286633', '00010', -17, -96]
# ['541267', '2018.03.12', 'TrRes.', '2021529033', '00010', -6, -102]
# ['541267', '2018.03.16', 'DepReq', '5223702', 0, -3, -105]
# ['541267', '2018.03.21', 'DepReq', '5223702', 0, -4, -109]
# ['541267', '2018.03.27', 'DepReq', '5223702', 0, -5, -114]
# ['541267', '2018.03.27', 'DepReq', '5225368', 0, -1, -115]
# ['541267', '2018.04.04', 'DepReq', '8032469', 0, -1, -116]
# ['541267', '2018.04.05', 'OrdRes', '3340585', 0, -2, -118]
# ['541267', '2018.04.05', 'DepReq', '5222561', 0, -9, -127]
# ['541267', '2018.04.05', 'DepReq', '5223702', 0, -5, -132]
# ['541267', '2018.04.05', 'DepReq', '5225368', 0, -7, -139]
# ['541267', '2018.04.06', 'OrdRes', '5224718', 0, -1, -140]
# ['541267', '2018.04.10', 'TrRes.', '2022286187', '00010', -73, -213]
# ['541267', '2018.04.10', 'TrRes.', '2022286478', '00010', -11, -224]
# ['541267', '2018.04.10', 'DepReq', '8032469', 0, -2, -226]
# ['541267', '2018.04.11', 'TrRes.', '2022286430', '00010', -18, -244]
# ['541267', '2018.04.11', 'DepReq', '5222561', 0, -14, -258]
# ['541267', '2018.04.11', 'DepReq', '5223702', 0, -3, -261]
# ['541267', '2018.04.12', 'OrdRes', '23000263', 0, -2, -263]
# ['541267', '2018.04.12', 'DepReq', '8079891', 0, -3, -266]
# ['541267', '2018.04.16', 'OrdRes', '23097289', 0, -2, -268]
# ['541267', '2018.04.16', 'DepReq', '5222561', 0, -4, -272]
# ['541267', '2018.04.16', 'DepReq', '5223702', 0, -1, -273]
# ['541267', '2018.04.17', 'DepReq', '5222561', 0, -12, -285]
# ['541267', '2018.04.17', 'DepReq', '5223702', 0, -5, -290]
# ['541267', '2018.04.17', 'DepReq', '5225368', 0, -2, -292]
# ['541267', '2018.04.17', 'DepReq', '8079891', 0, -4, -296]
# ['541267', '2018.04.17', 'DepReq', '8032469', 0, -1, -297]
# ['541267', '2018.04.17', 'DepReq', '8031369', 0, -1, -298]
# ['541267', '2018.04.20', 'OrdRes', '5225368', 0, -10, -308]
# ['541267', '2018.04.23', 'OrdRes', '11917079', 0, -1, -309]
# ['541267', '2018.04.23', 'DepReq', '8079891', 0, -4, -313]
# ['541267', '2018.04.23', 'DepReq', '8032469', 0, -1, -314]
# ['541267', '2018.04.24', 'OrdRes', '8031371', 0, -2, -316]
# ['541267', '2018.04.24', 'DepReq', '5223702', 0, -4, -320]
# ['541267', '2018.04.26', 'OrdRes', '5225368', 0, -10, -330]
# ['541267', '2018.04.27', 'DepReq', '8032469', 0, -1, -331]
# ['541267', '2018.04.30', 'DepReq', '8046634', 0, -1, -332]
# ['541267', '2018.05.02', 'OrdRes', '8040084', 0, -12, -344]
# ['541267', '2018.05.02', 'OrdRes', '8046634', 0, -1, -345]
# ['541267', '2018.05.02', 'DepReq', '5222561', 0, -12, -357]
# ['541267', '2018.05.02', 'DepReq', '5224718', 0, -1, -358]
# ['541267', '2018.05.03', 'OrdRes', '23000471', 0, -28, -386]
# ['541267', '2018.05.03', 'OrdRes', '8032469', 0, -1, -387]
# ['541267', '2018.05.04', 'RelOrd', '0066629468', '00001', -50, -437]
# ['541267', '2018.05.07', 'OrdRes', '8040088', 0, -12, -449]
# ['541267', '2018.05.07', 'OrdRes', '3340585', 0, -10, -459]
# ['541267', '2018.05.07', 'DepReq', '8032469', 0, -1, -460]
# ['541267', '2018.05.07', 'DepReq', '5197199', 0, -2, -462]
# ['541267', '2018.05.09', 'Order', '2211364577', '000010', -5, -467]
# ['541267', '2018.05.09', 'OrdRes', '570526', 0, -20, -487]
# ['541267', '2018.05.09', 'OrdRes', '5225368', 0, -10, -497]
# ['541267', '2018.05.09', 'OrdRes', '5225368', 0, -10, -507]
# ['541267', '2018.05.09', 'OrdRes', '11917075', 0, -1, -508]
# ['541267', '2018.05.11', 'OrdRes', '5223702', 0, -10, -518]
# ['541267', '2018.05.14', 'OrdRes', '8072192', 0, -10, -528]
# ['541267', '2018.05.14', 'OrdRes', '8072192', 0, -10, -538]
# ['541267', '2018.05.14', 'OrdRes', '23079402', 0, -2, -540]
# ['541267', '2018.05.15', 'OrdRes', '11917075', 0, -10, -550]
# ['541267', '2018.05.15', 'DepReq', '572254', 0, -1, -551]
# ['541267', '2018.05.15', 'DepReq', '8071440', 0, -1, -552]
# ['541267', '2018.05.15', 'DepReq', '560388', 0, -1, -553]
# ['541267', '2018.05.15', 'DepReq', '8032469', 0, -2, -555]
# ['541267', '2018.05.15', 'DepReq', '8031371', 0, -1, -556]
# ['541267', '2018.05.15', 'DepReq', '5197199', 0, -2, -558]
# ['541267', '2018.05.16', 'OrdRes', '23079402', 0, -4, -562]
# ['541267', '2018.05.17', 'DepReq', '5222561', 0, -20, -582]
# ['541267', '2018.05.17', 'DepReq', '5223702', 0, -5, -587]
# ['541267', '2018.05.18', 'RelOrd', '0066634402', '00001', -10, -597]
# ['541267', '2018.05.18', 'RelOrd', '0066638342', '00001', -40, -637]
# ['541267', '2018.05.18', 'RelOrd', '0066638343', '00001', -50, -687]
# ['541267', '2018.05.18', 'RelOrd', '0066638344', '00001', -10, -697]
# ['541267', '2018.05.18', 'RelOrd', '0066638731', '00001', -30, -727]
# ['541267', '2018.05.18', 'RelOrd', '0066638732', '00001', -10, -737]
# ['541267', '2018.05.22', 'OrdRes', '570526', 0, -20, -757]
# ['541267', '2018.05.22', 'OrdRes', '11917079', 0, -1, -758]
# ['541267', '2018.05.22', 'OrdRes', '8031371', 0, -1, -759]
# ['541267', '2018.05.22', 'OrdRes', '11917075', 0, -8, -767]
# ['541267', '2018.05.23', 'OrdRes', '8040088', 0, -12, -779]
# ['541267', '2018.05.23', 'OrdRes', '5225368', 0, -10, -789]
# ['541267', '2018.05.23', 'OrdRes', '5225368', 0, -10, -799]
# ['541267', '2018.05.23', 'OrdRes', '5197199', 0, -5, -804]
# ['541267', '2018.05.23', 'DepReq', '8032469', 0, -1, -805]
# ['541267', '2018.05.24', 'Deliv.', '1778064186', '000040', -1, -806]
# ['541267', '2018.05.24', 'Deliv.', '1778179107', '000150', -1, -807]
# ['541267', '2018.05.24', 'Order', '2500628408', '000120', -1, -808]
# ['541267', '2018.05.24', 'Order', '2560383254', '000020', -2, -810]
# ['541267', '2018.05.24', 'OrdRes', '8040086', 0, -12, -822]
# ['541267', '2018.05.25', 'OrdRes', '11917075', 0, -1, -823]
# ['541267', '2018.05.25', 'OrdRes', '23021388', 0, -2, -825]
# ['541267', '2018.05.25', 'OrdRes', '11917075', 0, -1, -826]
# ['541267', '2018.05.25', 'OrdRes', '23035572', 0, -10, -836]
# ['541267', '2018.05.25', 'OrdRes', '11917075', 0, -1, -837]
# ['541267', '2018.05.25', 'OrdRes', '23006739', 0, -1, -838]
# ['541267', '2018.05.25', 'DepReq', '5222561', 0, -10, -848]
# ['541267', '2018.05.25', 'DepReq', '5223702', 0, -4, -852]
# ['541267', '2018.05.28', 'Order', '2018385382', '000070', -1, -853]
# ['541267', '2018.05.28', 'Order', '2018402880', '000100', -9, -862]
# ['541267', '2018.05.28', 'Fr.del', '2018451397', '000020', -3, -865]
# ['541267', '2018.05.28', 'Order', '2018473442', '000010', -125, -990]
# ['541267', '2018.05.28', 'Order', '2018473515', '000010', -9, -999]
# ['541267', '2018.05.28', 'Order', '2018475909', '000250', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018476203', '000150', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018488086', '000400', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018489833', '000010', -6, 0]
# ['541267', '2018.05.28', 'Order', '2018492114', '000010', -20, 0]
# ['541267', '2018.05.28', 'Order', '2018493283', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018496666', '000080', -5, 0]
# ['541267', '2018.05.28', 'Order', '2018496902', '000010', -5, 0]
# ['541267', '2018.05.28', 'Order', '2018501968', '000090', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018502088', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018515500', '000070', -9, 0]
# ['541267', '2018.05.28', 'Order', '2018516782', '000170', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018517340', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018521494', '000010', -54, 0]
# ['541267', '2018.05.28', 'Order', '2018521505', '000010', -54, 0]
# ['541267', '2018.05.28', 'Order', '2018522153', '000510', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018522644', '000010', -54, 0]
# ['541267', '2018.05.28', 'Order', '2018532156', '000340', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018532159', '000340', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018532160', '000340', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018532761', '000230', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018537066', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018537366', '000050', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018543157', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018543157', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018544435', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018547159', '000010', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018550803', '000010', -7, 0]
# ['541267', '2018.05.28', 'Order', '2018552611', '000010', -16, 0]
# ['541267', '2018.05.28', 'Order', '2018555056', '000010', -18, 0]
# ['541267', '2018.05.28', 'Order', '2018559098', '000260', -4, 0]
# ['541267', '2018.05.28', 'Order', '2018563783', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018568450', '000010', -62, 0]
# ['541267', '2018.05.28', 'Order', '2018568724', '000010', -6, 0]
# ['541267', '2018.05.28', 'Order', '2018569348', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2018570740', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018572558', '000010', -132, 0]
# ['541267', '2018.05.28', 'Order', '2018575492', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018581022', '000010', -1, 0]
# ['541267', '2018.05.28', 'Fr.del', '2018586701', '000080', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018586880', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018587295', '000120', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018588019', '000090', -18, 0]
# ['541267', '2018.05.28', 'Order', '2018591535', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018603340', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018603364', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018603694', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018604348', '000010', -100, 0]
# ['541267', '2018.05.28', 'Order', '2018608048', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018608637', '000100', -40, 0]
# ['541267', '2018.05.28', 'Order', '2018608871', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018609561', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018609563', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018609753', '000060', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018612469', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018612645', '000330', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018613398', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018613400', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018613401', '000030', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018613402', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018615919', '000010', -25, 0]
# ['541267', '2018.05.28', 'Order', '2018625372', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018626135', '000210', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018627542', '000010', -5, 0]
# ['541267', '2018.05.28', 'Order', '2018630864', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018631164', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018631449', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018631477', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018632393', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018632396', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018632510', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018632982', '000060', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018635419', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018635707', '000010', -54, 0]
# ['541267', '2018.05.28', 'Order', '2018641135', '000100', -4, 0]
# ['541267', '2018.05.28', 'Order', '2018642417', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018647133', '000230', -20, 0]
# ['541267', '2018.05.28', 'Order', '2018648141', '000120', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018648146', '000010', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018651881', '000010', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018651882', '000010', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018651942', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018656916', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018656960', '000010', -20, 0]
# ['541267', '2018.05.28', 'Order', '2018657105', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018658490', '000080', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018658492', '000050', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018663614', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018663615', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018667358', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018668668', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018673747', '000010', -62, 0]
# ['541267', '2018.05.28', 'Order', '2018673757', '000010', -62, 0]
# ['541267', '2018.05.28', 'Order', '2018673828', '000010', -15, 0]
# ['541267', '2018.05.28', 'Order', '2018673850', '000010', -54, 0]
# ['541267', '2018.05.28', 'Order', '2018676346', '000220', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018678551', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018678606', '000010', -6, 0]
# ['541267', '2018.05.28', 'Order', '2018678737', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018679098', '000120', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018679101', '000220', -5, 0]
# ['541267', '2018.05.28', 'Order', '2018679340', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018679569', '000110', -11, 0]
# ['541267', '2018.05.28', 'Order', '2018683973', '000100', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018685060', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018685120', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018690342', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018694295', '000010', -7, 0]
# ['541267', '2018.05.28', 'Order', '2018694704', '000170', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018695264', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018695265', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018695930', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018695930', '000100', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018696139', '000180', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018700353', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018700377', '000150', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018700429', '000010', -40, 0]
# ['541267', '2018.05.28', 'Order', '2018700611', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018700614', '000110', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018700764', '000010', -30, 0]
# ['541267', '2018.05.28', 'Order', '2018703874', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018706191', '000010', -100, 0]
# ['541267', '2018.05.28', 'Order', '2018709493', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018711729', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018711730', '000020', -4, 0]
# ['541267', '2018.05.28', 'Order', '2018714986', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2018716076', '000010', -15, 0]
# ['541267', '2018.05.28', 'Order', '2018716538', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018720947', '000110', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018723324', '000290', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018725776', '000240', -13, 0]
# ['541267', '2018.05.28', 'Order', '2018727107', '000290', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018730659', '000140', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018730704', '000050', -1, 0]
# ['541267', '2018.05.28', 'Fr.del', '2018731165', '000050', -5, 0]
# ['541267', '2018.05.28', 'Order', '2018735157', '000010', -66, 0]
# ['541267', '2018.05.28', 'Order', '2018735299', '000110', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018735308', '000120', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018735565', '000010', -25, 0]
# ['541267', '2018.05.28', 'Order', '2018739658', '000010', -15, 0]
# ['541267', '2018.05.28', 'Order', '2018740058', '000010', -31, 0]
# ['541267', '2018.05.28', 'Order', '2018740311', '000010', -66, 0]
# ['541267', '2018.05.28', 'Order', '2018740565', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018740689', '000010', -62, 0]
# ['541267', '2018.05.28', 'Order', '2018743178', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018745806', '000280', -6, 0]
# ['541267', '2018.05.28', 'Order', '2018745819', '000010', -66, 0]
# ['541267', '2018.05.28', 'Order', '2018745884', '000010', -62, 0]
# ['541267', '2018.05.28', 'Order', '2018746873', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2018747000', '000080', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018750067', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018756274', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018760567', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018760803', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018760862', '000450', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018760878', '000450', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018761096', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018761408', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018766569', '000080', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018766841', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018767076', '000010', -7, 0]
# ['541267', '2018.05.28', 'Order', '2018767466', '000160', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018767467', '000120', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018767632', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018775930', '000010', -11, 0]
# ['541267', '2018.05.28', 'Order', '2018776284', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018776289', '000080', -4, 0]
# ['541267', '2018.05.28', 'Order', '2018780885', '000010', -30, 0]
# ['541267', '2018.05.28', 'Order', '2018780886', '000010', -30, 0]
# ['541267', '2018.05.28', 'Order', '2018780904', '000010', -3, 0]
# ['541267', '2018.05.28', 'Order', '2018782580', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018785550', '000010', -31, 0]
# ['541267', '2018.05.28', 'Order', '2018785705', '000200', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018786602', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2018787120', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2018787258', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2018787628', '000010', -18, 0]
# ['541267', '2018.05.28', 'Order', '2018790846', '000010', -60, 0]
# ['541267', '2018.05.28', 'Order', '2060666395', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2060668565', '000020', -20, 0]
# ['541267', '2018.05.28', 'Order', '2060670228', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2060675987', '000110', -1, 0]
# ['541267', '2018.05.28', 'Order', '2060677037', '000015', -1, 0]
# ['541267', '2018.05.28', 'Order', '2070606647', '000120', -4, 0]
# ['541267', '2018.05.28', 'Fr.del', '2070615239', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2070615355', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080518897', '000030', -4, 0]
# ['541267', '2018.05.28', 'Order', '2080519718', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080520372', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080524137', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080524222', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080524883', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080524965', '000120', -2, 0]
# ['541267', '2018.05.28', 'Order', '2080525643', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080525734', '000120', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080525944', '000170', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080525964', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080526025', '000120', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080526283', '000030', -2, 0]
# ['541267', '2018.05.28', 'Order', '2080526620', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080526850', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080528109', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080529116', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080530649', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2080532085', '000190', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090917525', '000370', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090919224', '000320', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090919849', '000010', -6, 0]
# ['541267', '2018.05.28', 'Order', '2090919850', '000010', -6, 0]
# ['541267', '2018.05.28', 'Order', '2090922328', '000240', -7, 0]
# ['541267', '2018.05.28', 'Order', '2090923042', '000080', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090924608', '000180', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090924608', '000190', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090924826', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090926549', '000240', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090926928', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090927161', '000070', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090927326', '001100', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090927841', '000390', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090927903', '000100', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090927945', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090930164', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090930206', '000080', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090930238', '000060', -35, 0]
# ['541267', '2018.05.28', 'Order', '2090930399', '000020', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090930981', '000150', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090931787', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090932731', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090932853', '000520', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090932853', '000530', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090932853', '000540', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090932914', '000010', -10, 0]
# ['541267', '2018.05.28', 'Order', '2090933054', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090933276', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090935054', '000160', -5, 0]
# ['541267', '2018.05.28', 'Order', '2090935397', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090936039', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090936452', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090937006', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090937450', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090937599', '000120', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090938135', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090938240', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090938804', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090939627', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090940583', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090941188', '000150', -10, 0]
# ['541267', '2018.05.28', 'Fr.del', '2090942593', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090942726', '000030', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090943578', '000280', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090943765', '000240', -3, 0]
# ['541267', '2018.05.28', 'Order', '2090943778', '000041', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090944188', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090944205', '000120', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090944463', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090944610', '000070', -7, 0]
# ['541267', '2018.05.28', 'Order', '2090944676', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090944680', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090946127', '000040', -7, 0]
# ['541267', '2018.05.28', 'Order', '2090946601', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090946746', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090947247', '000271', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090947586', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090947782', '000130', -3, 0]
# ['541267', '2018.05.28', 'Order', '2090947962', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090947966', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090947968', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090947970', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090948046', '000050', -8, 0]
# ['541267', '2018.05.28', 'Order', '2090948213', '000140', -5, 0]
# ['541267', '2018.05.28', 'Order', '2090948225', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090948342', '000020', -20, 0]
# ['541267', '2018.05.28', 'Order', '2090948476', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090948804', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090948849', '000170', -20, 0]
# ['541267', '2018.05.28', 'Order', '2090948996', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090949600', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090950450', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090950515', '000100', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090951398', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090951400', '000030', -15, 0]
# ['541267', '2018.05.28', 'Order', '2090951423', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090951427', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090951431', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090952285', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090952365', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090952480', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090953656', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090953735', '000100', -3, 0]
# ['541267', '2018.05.28', 'Order', '2090953815', '000180', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090953829', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090953870', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090953873', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090954472', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090954545', '000340', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090954731', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090955828', '000080', -10, 0]
# ['541267', '2018.05.28', 'Order', '2090956832', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090957000', '000110', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090957018', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090957102', '000730', -2, 0]
# ['541267', '2018.05.28', 'Order', '2090957122', '000750', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090957122', '000760', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090957122', '000770', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090957796', '000310', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090958987', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090958987', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090958987', '000200', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090960128', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090960956', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2090960997', '000290', -1, 0]
# ['541267', '2018.05.28', 'Order', '2090961094', '000020', -10, 0]
# ['541267', '2018.05.28', 'Order', '2090961610', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100493945', '000130', -4, 0]
# ['541267', '2018.05.28', 'Order', '2100494050', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100495172', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100495254', '000040', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100495547', '000070', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100495667', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100497167', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100497537', '000050', -3, 0]
# ['541267', '2018.05.28', 'Order', '2100497879', '000040', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100499292', '000040', -3, 0]
# ['541267', '2018.05.28', 'Order', '2100499542', '000070', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100499904', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100499998', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100501051', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100501184', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100501347', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100502602', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100502772', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100502887', '000070', -5, 0]
# ['541267', '2018.05.28', 'Order', '2100503369', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100503778', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2100504429', '000010', -3, 0]
# ['541267', '2018.05.28', 'Order', '2100504645', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100505096', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100505205', '000040', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100505514', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100507094', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100507341', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100508110', '000030', -2, 0]
# ['541267', '2018.05.28', 'Order', '2100508457', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100509061', '000030', -20, 0]
# ['541267', '2018.05.28', 'Order', '2100509186', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2100509563', '000140', -4, 0]
# ['541267', '2018.05.28', 'Order', '2100510598', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2110346054', '000060', -2, 0]
# ['541267', '2018.05.28', 'Order', '2110346262', '000070', -2, 0]
# ['541267', '2018.05.28', 'Order', '2110346476', '000330', -2, 0]
# ['541267', '2018.05.28', 'Order', '2110348092', '000100', -1, 0]
# ['541267', '2018.05.28', 'Order', '2110348115', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2110348516', '000050', -2, 0]
# ['541267', '2018.05.28', 'Order', '2110348524', '000070', -10, 0]
# ['541267', '2018.05.28', 'Order', '2110349068', '000030', -2, 0]
# ['541267', '2018.05.28', 'Order', '2120379666', '000010', -3, 0]
# ['541267', '2018.05.28', 'Order', '2120384184', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2120385944', '000030', -3, 0]
# ['541267', '2018.05.28', 'Order', '2120386982', '000100', -1, 0]
# ['541267', '2018.05.28', 'Order', '2120387225', '000030', -2, 0]
# ['541267', '2018.05.28', 'Order', '2120387516', '000020', -8, 0]
# ['541267', '2018.05.28', 'Order', '2130564188', '000250', -4, 0]
# ['541267', '2018.05.28', 'Order', '2130564905', '000790', -1, 0]
# ['541267', '2018.05.28', 'Order', '2130570000', '000030', -6, 0]
# ['541267', '2018.05.28', 'Order', '2130570521', '000110', -1, 0]
# ['541267', '2018.05.28', 'Order', '2130573307', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2130573973', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2130580674', '000730', -6, 0]
# ['541267', '2018.05.28', 'Order', '2140769277', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140769604', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140775024', '000300', -10, 0]
# ['541267', '2018.05.28', 'Order', '2140775044', '000080', -2, 0]
# ['541267', '2018.05.28', 'Order', '2140775376', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140775411', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140775843', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140776507', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140777316', '001400', -10, 0]
# ['541267', '2018.05.28', 'Order', '2140777758', '000270', -7, 0]
# ['541267', '2018.05.28', 'Order', '2140777803', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140777818', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140778363', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140778386', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140779331', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140779335', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140780175', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2140781675', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140781678', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140782298', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140782421', '000270', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140784457', '000080', -8, 0]
# ['541267', '2018.05.28', 'Order', '2140784732', '000330', -10, 0]
# ['541267', '2018.05.28', 'Order', '2140784742', '000060', -10, 0]
# ['541267', '2018.05.28', 'Order', '2140785248', '001620', -2, 0]
# ['541267', '2018.05.28', 'Order', '2140785288', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140786010', '000150', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140786468', '000150', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140788247', '000180', -4, 0]
# ['541267', '2018.05.28', 'Order', '2140788766', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140789155', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140789713', '000070', -2, 0]
# ['541267', '2018.05.28', 'Order', '2140789801', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140789914', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140792889', '000390', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140793051', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140793054', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140793058', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140793061', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140793064', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140793065', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140793388', '000590', -4, 0]
# ['541267', '2018.05.28', 'Order', '2140794304', '000480', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140794492', '000020', -10, 0]
# ['541267', '2018.05.28', 'Order', '2140794593', '000220', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140794696', '000070', -2, 0]
# ['541267', '2018.05.28', 'Order', '2140794997', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140795653', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140796912', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2140797683', '000320', -20, 0]
# ['541267', '2018.05.28', 'Order', '2140798504', '000020', -5, 0]
# ['541267', '2018.05.28', 'Order', '2140798857', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2140799786', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2150422189', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2150424357', '000040', -10, 0]
# ['541267', '2018.05.28', 'Order', '2150425848', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2150429573', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2160176015', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2180238973', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2180239004', '000240', -1, 0]
# ['541267', '2018.05.28', 'Order', '2180239511', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2180240489', '000070', -3, 0]
# ['541267', '2018.05.28', 'Fr.del', '2180240895', '000090', -2, 0]
# ['541267', '2018.05.28', 'Order', '2180241729', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2180242385', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2180242385', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2180242608', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2190170907', '000020', -1, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211162090', '000360', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211307390', '000210', -1, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211314109', '000120', -4, 0]
# ['541267', '2018.05.28', 'Order', '2211314412', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211321279', '000060', -3, 0]
# ['541267', '2018.05.28', 'Order', '2211321423', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211329727', '000020', -3, 0]
# ['541267', '2018.05.28', 'Order', '2211330655', '000020', -3, 0]
# ['541267', '2018.05.28', 'Order', '2211348567', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211351111', '000100', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211351179', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211351650', '000050', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211352711', '000170', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211352902', '000130', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211352950', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211352974', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211354686', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211362368', '000100', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211364082', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211364295', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211368755', '000050', -10, 0]
# ['541267', '2018.05.28', 'Order', '2211370816', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211371732', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211373647', '000020', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211384629', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211393725', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211396284', '000030', -5, 0]
# ['541267', '2018.05.28', 'Order', '2211400007', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211417551', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211419961', '000110', -5, 0]
# ['541267', '2018.05.28', 'Order', '2211424844', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211434210', '000160', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211434390', '000100', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211434845', '000430', -20, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211435697', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211438847', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211439636', '000020', -7, 0]
# ['541267', '2018.05.28', 'Order', '2211441359', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211446767', '000200', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211448471', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2211448874', '000090', -100, 0]
# ['541267', '2018.05.28', 'Order', '2211450845', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211451164', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211453307', '000040', -5, 0]
# ['541267', '2018.05.28', 'Order', '2211453418', '000090', -1, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211453830', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211456055', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211457286', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211460173', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211461668', '000020', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211462036', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211464926', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211465710', '000120', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211467562', '000090', -1, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211468195', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211468230', '000230', -30, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211474984', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211475994', '000070', -8, 0]
# ['541267', '2018.05.28', 'Order', '2211476310', '000020', -7, 0]
# ['541267', '2018.05.28', 'Order', '2211483315', '000020', -4, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211484190', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211484956', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211485954', '000060', -1, 0]
# ['541267', '2018.05.28', 'Fr.del', '2211488936', '000090', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211489471', '000010', -5, 0]
# ['541267', '2018.05.28', 'Order', '2211491423', '000390', -2, 0]
# ['541267', '2018.05.28', 'Order', '2211497876', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211498450', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211504311', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211506222', '000210', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211512496', '000140', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211517215', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2211526426', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500617814', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500619207', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500626152', '000080', -4, 0]
# ['541267', '2018.05.28', 'Order', '2500626322', '000360', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500626332', '000360', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500626333', '000360', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500626341', '000360', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500626694', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500629026', '000010', -4, 0]
# ['541267', '2018.05.28', 'Order', '2500630423', '000030', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500630944', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500632437', '000180', -1, 0]
# ['541267', '2018.05.28', 'Order', '2500639529', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2510644679', '000070', -1, 0]
# ['541267', '2018.05.28', 'Order', '2510644683', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2510649964', '000130', -1, 0]
# ['541267', '2018.05.28', 'Order', '2510654605', '000190', -1, 0]
# ['541267', '2018.05.28', 'Order', '2510657261', '000010', -2, 0]
# ['541267', '2018.05.28', 'Order', '2510658064', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2540258288', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2540260029', '000070', -3, 0]
# ['541267', '2018.05.28', 'Order', '2540260029', '000080', -2, 0]
# ['541267', '2018.05.28', 'Order', '2540260131', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2540263029', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2540263034', '000080', -1, 0]
# ['541267', '2018.05.28', 'Order', '2540263180', '000110', -1, 0]
# ['541267', '2018.05.28', 'Order', '2550208622', '000040', -1, 0]
# ['541267', '2018.05.28', 'Order', '2560386485', '000040', -2, 0]
# ['541267', '2018.05.28', 'Order', '2560389166', '000320', -2, 0]
# ['541267', '2018.05.28', 'Order', '2560391091', '000180', -6, 0]
# ['541267', '2018.05.28', 'Order', '2560391188', '000060', -1, 0]
# ['541267', '2018.05.28', 'Order', '2570146574', '000050', -2, 0]
# ['541267', '2018.05.28', 'Order', '2570147048', '000070', -4, 0]
# ['541267', '2018.05.28', 'Order', '2570147325', '000150', -1, 0]
# ['541267', '2018.05.28', 'Order', '2570147685', '000350', -1, 0]
# ['541267', '2018.05.28', 'Order', '2590180665', '000050', -1, 0]
# ['541267', '2018.05.28', 'Order', '2630167977', '000010', -8, 0]
# ['541267', '2018.05.28', 'Order', '2630168716', '000010', -5, 0]
# ['541267', '2018.05.28', 'Order', '2630168972', '000020', -1, 0]
# ['541267', '2018.05.28', 'Order', '2680207084', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2680208774', '000060', -2, 0]
# ['541267', '2018.05.28', 'Order', '2690225907', '000010', -1, 0]
# ['541267', '2018.05.28', 'Order', '2760100487', '000180', -2, 0]
# ['541267', '2018.05.28', 'Order', '2760100624', '000200', -3, 0]
# ['541267', '2018.05.28', 'Order', '2760100713', '000110', -50, 0]
# ['541267', '2018.05.28', 'OrdRes', '23091918', 0, -3, 0]
# ['541267', '2018.05.28', 'OrdRes', '11917075', 0, -1, 0]
# ['541267', '2018.05.28', 'OrdRes', '23021882', 0, -15, 0]
# ['541267', '2018.05.28', 'OrdRes', '8079891', 0, -2, 0]
# ['541267', '2018.05.28', 'DepReq', '8072192', 0, -4, 0]
# ['541267', '2018.05.28', 'DepReq', '8089319', 0, -1, 0]
# ['541267', '2018.05.28', 'DepReq', '8046634', 0, -1, 0]
# ['541267', '2018.05.29', 'Order', '2018521396', '000010', -31, 0]
# ['541267', '2018.05.29', 'Order', '2018552358', '000010', -25, 0]
# ['541267', '2018.05.29', 'Order', '2018656961', '000010', -25, 0]
# ['541267', '2018.05.29', 'Order', '2018725888', '000080', -1, 0]
# ['541267', '2018.05.29', 'Order', '2018771279', '000080', -3, 0]
# ['541267', '2018.05.29', 'Order', '2090955839', '000090', -4, 0]
# ['541267', '2018.05.29', 'Order', '2140793952', '000080', -10, 0]
# ['541267', '2018.05.29', 'Order', '2140799810', '000020', -1, 0]
# ['541267', '2018.05.29', 'Order', '2140800425', '000030', -2, 0]
# ['541267', '2018.05.29', 'Order', '2140800511', '000040', -2, 0]
# ['541267', '2018.05.29', 'Order', '2211517215', '000100', -1, 0]
# ['541267', '2018.05.29', 'OrdRes', '11917113', 0, -2, 0]
# ['541267', '2018.05.29', 'OrdRes', '11917075', 0, -1, 0]
# ['541267', '2018.05.29', 'OrdRes', '11917075', 0, -1, 0]
# ['541267', '2018.05.29', 'OrdRes', '5222561', 0, -20, 0]
# ['541267', '2018.05.29', 'OrdRes', '8079891', 0, -4, 0]
# ['541267', '2018.05.29', 'OrdRes', '8079891', 0, -3, 0]
# ['541267', '2018.05.30', 'Deliv.', '1778299032', '000010', -40, 0]
# ['541267', '2018.05.30', 'Order', '2018791887', '000010', -25, 0]
# ['541267', '2018.05.30', 'Order', '2090953068', '000070', -1, 0]
# ['541267', '2018.05.30', 'Order', '2090957147', '000070', -1, 0]
# ['541267', '2018.05.30', 'Order', '2100509208', '000010', -7, 0]
# ['541267', '2018.05.30', 'Order', '2130577825', '000010', -3, 0]
# ['541267', '2018.05.30', 'Order', '2140795753', '000020', -1, 0]
# ['541267', '2018.05.30', 'OrdRes', '23009765', 0, -3, 0]
# ['541267', '2018.05.30', 'OrdRes', '11917075', 0, -8, 0]
# ['541267', '2018.05.30', 'OrdRes', '23000263', 0, -2, 0]
# ['541267', '2018.05.30', 'OrdRes', '11917075', 0, -1, 0]
# ['541267', '2018.05.30', 'OrdRes', '23105196', 0, -2, 0]
# ['541267', '2018.05.30', 'OrdRes', '11917113', 0, -1, 0]
# ['541267', '2018.05.30', 'DepReq', '8032469', 0, -1, 0]
# ['541267', '2018.05.30', 'DepReq', '5197199', 0, -2, 0]
# ['541267', '2018.06.01', 'Order', '2018766842', '000030', -2, 0]
# ['541267', '2018.06.01', 'Order', '2018766843', '000060', -2, 0]
# ['541267', '2018.06.01', 'Order', '2090954759', '000010', -1, 0]
# ['541267', '2018.06.01', 'OrdRes', '23015255', 0, -1, 0]
# ['541267', '2018.06.01', 'OrdRes', '5225368', 0, -10, 0]
# ['541267', '2018.06.01', 'RelOrd', '0066614097', '00001', -150, 0]
# ['541267', '2018.06.01', 'RelOrd', '0066639146', '00001', -5, 0]
# ['541267', '2018.06.04', 'Order', '2018796902', '000010', -7, 0]
# ['541267', '2018.06.04', 'Order', '2090957894', '000020', -1, 0]
# ['541267', '2018.06.04', 'Order', '2090959332', '000110', -5, 0]
# ['541267', '2018.06.04', 'Order', '2090960173', '000020', -1, 0]
# ['541267', '2018.06.04', 'Order', '2090961525', '000010', -1, 0]
# ['541267', '2018.06.04', 'Order', '2090962694', '000110', -1, 0]
# ['541267', '2018.06.04', 'Order', '2211519996', '000130', -1, 0]
# ['541267', '2018.06.04', 'OrdRes', '23105196', 0, -1, 0]
# ['541267', '2018.06.04', 'OrdRes', '8040088', 0, -12, 0]
# ['541267', '2018.06.04', 'RelOrd', '0066639978', '00001', -85, 0]
# ['541267', '2018.06.04', 'DepReq', '5222561', 0, -8, 0]
# ['541267', '2018.06.04', 'DepReq', '5223702', 0, -5, 0]
# ['541267', '2018.06.04', 'DepReq', '8072192', 0, -5, 0]
# ['541267', '2018.06.05', 'Order', '2100503224', '000070', -2, 0]
# ['541267', '2018.06.05', 'Order', '2211503316', '000040', -1, 0]
# ['541267', '2018.06.05', 'Order', '2211509837', '000200', -3, 0]
# ['541267', '2018.06.05', 'OrdRes', '3340585', 0, -3, 0]
# ['541267', '2018.06.05', 'OrdRes', '560388', 0, -2, 0]
# ['541267', '2018.06.05', 'OrdRes', '570526', 0, -20, 0]
# ['541267', '2018.06.05', 'OrdRes', '11917075', 0, -1, 0]
# ['541267', '2018.06.05', 'RelOrd', '0066639703', '00001', -15, 0]
# ['541267', '2018.06.05', 'RelOrd', '0066639979', '00001', -15, 0]
# ['541267', '2018.06.05', 'DepReq', '8046634', 0, -1, 0]
# ['541267', '2018.06.06', 'ShipNt', '1045885707', '00001', 84, 0]
# ['541267', '2018.06.06', 'ShipNt', '1045914806', '00001', 168, 0]
# ['541267', '2018.06.06', 'Order', '2018622220', '000140', -1, 0]
# ['541267', '2018.06.06', 'Order', '2018766840', '000050', -1, 0]
# ['541267', '2018.06.06', 'Order', '2090939279', '000770', -1, 0]
# ['541267', '2018.06.06', 'Order', '2090960305', '000110', -1, 0]
# ['541267', '2018.06.06', 'Order', '2100503107', '000070', -1, 0]
# ['541267', '2018.06.06', 'Order', '2211448745', '000090', -5, 0]
# ['541267', '2018.06.06', 'OrdRes', '23019841', 0, -1, 0]
# ['541267', '2018.06.06', 'OrdRes', '23056031', 0, -2, 0]
# ['541267', '2018.06.06', 'OrdRes', '23079402', 0, -2, 0]
# ['541267', '2018.06.06', 'OrdRes', '23021271', 0, -2, 0]
# ['541267', '2018.06.07', 'Order', '2211525534', '000010', -1, 0]
# ['541267', '2018.06.07', 'Order', '2211528672', '000120', -8, 0]
# ['541267', '2018.06.07', 'OrdRes', '23091918', 0, -1, 0]
# ['541267', '2018.06.07', 'OrdRes', '11917075', 0, -1, 0]
# ['541267', '2018.06.07', 'DepReq', '8032469', 0, -1, 0]
# ['541267', '2018.06.07', 'DepReq', '5197199', 0, -2, 0]
# ['541267', '2018.06.08', 'Order', '2211291658', '000030', -6, 0]
# ...
# Type          DepReq
# DocNum       5223702
# Pos                0
# Change            -5
# Avail           -132
# Name: 13, dtype: object
# Partnr        541267
# Date      2018.04.05
# Type          DepReq
# DocNum       5225368
# Pos                0
# Change            -7
# Avail           -139
# Name: 14, dtype: object
# Partnr        541267
# Date      2018.04.06
# Type          OrdRes
# DocNum       5224718
# Pos                0
# Change            -1
# Avail           -140
# Name: 15, dtype: object
# Partnr        541267
# Date      2018.04.10
# Type          TrRes.
# DocNum    2022286187
# Pos            00010
# Change           -73
# Avail           -213
# Name: 16, dtype: object
# Partnr        541267
# Date      2018.04.10
# Type          TrRes.
# DocNum    2022286478
# Pos            00010
# Change           -11
# Avail           -224
# Name: 17, dtype: object
# Partnr        541267
# Date      2018.04.10
# Type          DepReq
# DocNum       8032469
# Pos                0
# Change            -2
# Avail           -226
# Name: 18, dtype: object
# Partnr        541267
# Date      2018.04.11
# Type          TrRes.
# DocNum    2022286430
# Pos            00010
# Change           -18
# Avail           -244
# Name: 19, dtype: object
# Partnr        541267
# Date      2018.04.11
# Type          DepReq
# DocNum       5222561
# Pos                0
# Change           -14
# Avail           -258
# Name: 20, dtype: object
# Partnr        541267
# Date      2018.04.11
# Type          DepReq
# DocNum       5223702
# Pos                0
# Change            -3
# Avail           -261
# Name: 21, dtype: object
# Partnr        541267
# Date      2018.04.12
# Type          OrdRes
# DocNum      23000263
# Pos                0
# Change            -2
# Avail           -263
# Name: 22, dtype: object
# Partnr        541267
# Date      2018.04.12
# Type          DepReq
# DocNum       8079891
# Pos                0
# Change            -3
# Avail           -266
# Name: 23, dtype: object
# Partnr        541267
# Date      2018.04.16
# Type          OrdRes
# DocNum      23097289
# Pos                0
# Change            -2
# Avail           -268
# Name: 24, dtype: object
# Partnr        541267
# Date      2018.04.16
# Type          DepReq
# DocNum       5222561
# Pos                0
# Change            -4
# Avail           -272
# Name: 25, dtype: object
# Partnr        541267
# Date      2018.04.16
# Type          DepReq
# DocNum       5223702
# Pos                0
# Change            -1
# Avail           -273
# Name: 26, dtype: object
# Partnr        541267
# Date      2018.04.17
# Type          DepReq
# DocNum       5222561
# Pos                0
# Change           -12
# Avail           -285
# Name: 27, dtype: object
# Partnr        541267
# Date      2018.04.17
# Type          DepReq
# DocNum       5223702
# Pos                0
# Change            -5
# Avail           -290
# Name: 28, dtype: object
# Partnr        541267
# Date      2018.04.17
# Type          DepReq
# DocNum       5225368
# Pos                0
# Change            -2
# Avail           -292
# Name: 29, dtype: object
# Partnr        541267
# Date      2018.04.17
# Type          DepReq
# DocNum       8079891
# Pos                0
# Change            -4
# Avail           -296
# Name: 30, dtype: object
# Partnr        541267
# Date      2018.04.17
# Type          DepReq
# DocNum       8032469
# Pos                0
# Change            -1
# Avail           -297
# Name: 31, dtype: object
# Partnr        541267
# Date      2018.04.17
# Type          DepReq
# DocNum       8031369
# Pos                0
# Change            -1
# Avail           -298
# Name: 32, dtype: object
# Partnr        541267
# Date      2018.04.20
# Type          OrdRes
# DocNum       5225368
# Pos                0
# Change           -10
# Avail           -308
# Name: 33, dtype: object
# Partnr        541267
# Date      2018.04.23
# Type          OrdRes
# DocNum      11917079
# Pos                0
# Change            -1
# Avail           -309
# Name: 34, dtype: object
# Partnr        541267
# Date      2018.04.23
# Type          DepReq
# DocNum       8079891
# Pos                0
# Change            -4
# Avail           -313
# Name: 35, dtype: object
# Partnr        541267
# Date      2018.04.23
# Type          DepReq
# DocNum       8032469
# Pos                0
# Change            -1
# Avail           -314
# Name: 36, dtype: object
# Partnr        541267
# Date      2018.04.24
# Type          OrdRes
# DocNum       8031371
# Pos                0
# Change            -2
# Avail           -316
# Name: 37, dtype: object
# Partnr        541267
# Date      2018.04.24
# Type          DepReq
# DocNum       5223702
# Pos                0
# Change            -4
# Avail           -320
# Name: 38, dtype: object
# Partnr        541267
# Date      2018.04.26
# Type          OrdRes
# DocNum       5225368
# Pos                0
# Change           -10
# Avail           -330
# Name: 39, dtype: object
# Partnr        541267
# Date      2018.04.27
# Type          DepReq
# DocNum       8032469
# Pos                0
# Change            -1
# Avail           -331
# Name: 40, dtype: object
# Partnr        541267
# Date      2018.04.30
# Type          DepReq
# DocNum       8046634
# Pos                0
# Change            -1
# Avail           -332
# Name: 41, dtype: object
# Partnr        541267
# Date      2018.05.02
# Type          OrdRes
# DocNum       8040084
# Pos                0
# Change           -12
# Avail           -344
# Name: 42, dtype: object
# Partnr        541267
# Date      2018.05.02
# Type          OrdRes
# DocNum       8046634
# Pos                0
# Change            -1
# Avail           -345
# Name: 43, dtype: object
# Partnr        541267
# Date      2018.05.02
# Type          DepReq
# DocNum       5222561
# Pos                0
# Change           -12
# Avail           -357
# Name: 44, dtype: object
# Partnr        541267
# Date      2018.05.02
# Type          DepReq
# DocNum       5224718
# Pos                0
# Change            -1
# Avail           -358
# Name: 45, dtype: object
# Partnr        541267
# Date      2018.05.03
# Type          OrdRes
# DocNum      23000471
# Pos                0
# Change           -28
# Avail           -386
# Name: 46, dtype: object
# Partnr        541267
# Date      2018.05.03
# Type          OrdRes
# DocNum       8032469
# Pos                0
# Change            -1
# Avail           -387
# Name: 47, dtype: object
# Partnr        541267
# Date      2018.05.04
# Type          RelOrd
# DocNum    0066629468
# Pos            00001
# Change           -50
# Avail           -437
# Name: 48, dtype: object
# Partnr        541267
# Date      2018.05.07
# Type          OrdRes
# DocNum       8040088
# Pos                0
# Change           -12
# Avail           -449
# Name: 49, dtype: object
# Partnr        541267
# Date      2018.05.07
# Type          OrdRes
# DocNum       3340585
# Pos                0
# Change           -10
# Avail           -459
# Name: 50, dtype: object
# Partnr        541267
# Date      2018.05.07
# Type          DepReq
# DocNum       8032469
# Pos                0
# Change            -1
# Avail           -460
# Name: 51, dtype: object
# Partnr        541267
# Date      2018.05.07
# Type          DepReq
# DocNum       5197199
# Pos                0
# Change            -2
# Avail           -462
# Name: 52, dtype: object
# Partnr        541267
# Date      2018.05.09
# Type           Order
# DocNum    2211364577
# Pos           000010
# Change            -5
# Avail           -467
# Name: 53, dtype: object
# Partnr        541267
# Date      2018.05.09
# Type          OrdRes
# DocNum        570526
# Pos                0
# Change           -20
# Avail           -487
# Name: 54, dtype: object
# Partnr        541267
# Date      2018.05.09
# Type          OrdRes
# DocNum       5225368
# Pos                0
# Change           -10
# Avail           -497
# Name: 55, dtype: object
# Partnr        541267
# Date      2018.05.09
# Type          OrdRes
# DocNum       5225368
# Pos                0
# Change           -10
# Avail           -507
# Name: 56, dtype: object
# Partnr        541267
# Date      2018.05.09
# Type          OrdRes
# DocNum      11917075
# Pos                0
# Change            -1
# Avail           -508
# Name: 57, dtype: object
# Partnr        541267
# Date      2018.05.11
# Type          OrdRes
# DocNum       5223702
# Pos                0
# Change           -10
# Avail           -518
# Name: 58, dtype: object
# Partnr        541267
# Date      2018.05.14
# Type          OrdRes
# DocNum       8072192
# Pos                0
# Change           -10
# Avail           -528
# Name: 59, dtype: object
# Partnr        541267
# Date      2018.05.14
# Type          OrdRes
# DocNum       8072192
# Pos                0
# Change           -10
# Avail           -538
# Name: 60, dtype: object
# Partnr        541267
# Date      2018.05.14
# Type          OrdRes
# DocNum      23079402
# Pos                0
# Change            -2
# Avail           -540
# Name: 61, dtype: object
# Partnr        541267
# Date      2018.05.15
# Type          OrdRes
# DocNum      11917075
# Pos                0
# Change           -10
# Avail           -550
# Name: 62, dtype: object
# Partnr        541267
# Date      2018.05.15
# Type          DepReq
# DocNum        572254
# Pos                0
# Change            -1
# Avail           -551
# Name: 63, dtype: object
# Partnr        541267
# Date      2018.05.15
# Type          DepReq
# DocNum       8071440
# Pos                0
# Change            -1
# Avail           -552
# Name: 64, dtype: object
# Partnr        541267
# Date      2018.05.15
# Type          DepReq
# DocNum        560388
# Pos                0
# Change            -1
# Avail           -553
# Name: 65, dtype: object
# Partnr        541267
# Date      2018.05.15
# Type          DepReq
# DocNum       8032469
# Pos                0
# Change            -2
# Avail           -555
# Name: 66, dtype: object
# Partnr        541267
# Date      2018.05.15
# Type          DepReq
# DocNum       8031371
# Pos                0
# Change            -1
# Avail           -556
# Name: 67, dtype: object
# Partnr        541267
# Date      2018.05.15
# Type          DepReq
# DocNum       5197199
# Pos                0
# Change            -2
# Avail           -558
# Name: 68, dtype: object
# Partnr        541267
# Date      2018.05.16
# Type          OrdRes
# DocNum      23079402
# Pos                0
# Change            -4
# Avail           -562
# Name: 69, dtype: object
# Partnr        541267
# Date      2018.05.17
# Type          DepReq
# DocNum       5222561
# Pos                0
# Change           -20
# Avail           -582
# Name: 70, dtype: object
# Partnr        541267
# Date      2018.05.17
# Type          DepReq
# DocNum       5223702
# Pos                0
# Change            -5
# Avail           -587
# Name: 71, dtype: object
# Partnr        541267
# Date      2018.05.18
# Type          RelOrd
# DocNum    0066634402
# Pos            00001
# Change           -10
# Avail           -597
# Name: 72, dtype: object
# Partnr        541267
# Date      2018.05.18
# Type          RelOrd
# DocNum    0066638342
# Pos            00001
# Change           -40
# Avail           -637
# Name: 73, dtype: object
# Partnr        541267
# Date      2018.05.18
# Type          RelOrd
# DocNum    0066638343
# Pos            00001
# Change           -50
# Avail           -687
# Name: 74, dtype: object
# Partnr        541267
# Date      2018.05.18
# Type          RelOrd
# DocNum    0066638344
# Pos            00001
# Change           -10
# Avail           -697
# Name: 75, dtype: object
# Partnr        541267
# Date      2018.05.18
# Type          RelOrd
# DocNum    0066638731
# Pos            00001
# Change           -30
# Avail           -727
# Name: 76, dtype: object
# Partnr        541267
# Date      2018.05.18
# Type          RelOrd
# DocNum    0066638732
# Pos            00001
# Change           -10
# Avail           -737
# Name: 77, dtype: object
# Partnr        541267
# Date      2018.05.22
# Type          OrdRes
# DocNum        570526
# Pos                0
# Change           -20
# Avail           -757
# Name: 78, dtype: object
# Partnr        541267
# Date      2018.05.22
# Type          OrdRes
# DocNum      11917079
# Pos                0
# Change            -1
# Avail           -758
# Name: 79, dtype: object
# Partnr        541267
# Date      2018.05.22
# Type          OrdRes
# DocNum       8031371
# Pos                0
# Change            -1
# Avail           -759
# Name: 80, dtype: object
# Partnr        541267
# Date      2018.05.22
# Type          OrdRes
# DocNum      11917075
# Pos                0
# Change            -8
# Avail           -767
# Name: 81, dtype: object
# Partnr        541267
# Date      2018.05.23
# Type          OrdRes
# DocNum       8040088
# Pos                0
# Change           -12
# Avail           -779
# Name: 82, dtype: object
# Partnr        541267
# Date      2018.05.23
# Type          OrdRes
# DocNum       5225368
# Pos                0
# Change           -10
# Avail           -789
# Name: 83, dtype: object
# Partnr        541267
# Date      2018.05.23
# Type          OrdRes
# DocNum       5225368
# Pos                0
# Change           -10
# Avail           -799
# Name: 84, dtype: object
# Partnr        541267
# Date      2018.05.23
# Type          OrdRes
# DocNum       5197199
# Pos                0
# Change            -5
# Avail           -804
# Name: 85, dtype: object
# Partnr        541267
# Date      2018.05.23
# Type          DepReq
# DocNum       8032469
# Pos                0
# Change            -1
# Avail           -805
# Name: 86, dtype: object
# Partnr        541267
# Date      2018.05.24
# Type          Deliv.
# DocNum    1778064186
# Pos           000040
# Change            -1
# Avail           -806
# Name: 87, dtype: object
# Partnr        541267
# Date      2018.05.24
# Type          Deliv.
# DocNum    1778179107
# Pos           000150
# Change            -1
# Avail           -807
# Name: 88, dtype: object
# Partnr        541267
# Date      2018.05.24
# Type           Order
# DocNum    2500628408
# Pos           000120
# Change            -1
# Avail           -808
# Name: 89, dtype: object
# Partnr        541267
# Date      2018.05.24
# Type           Order
# DocNum    2560383254
# Pos           000020
# Change            -2
# Avail           -810
# Name: 90, dtype: object
# Partnr        541267
# Date      2018.05.24
# Type          OrdRes
# DocNum       8040086
# Pos                0
# Change           -12
# Avail           -822
# Name: 91, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          OrdRes
# DocNum      11917075
# Pos                0
# Change            -1
# Avail           -823
# Name: 92, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          OrdRes
# DocNum      23021388
# Pos                0
# Change            -2
# Avail           -825
# Name: 93, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          OrdRes
# DocNum      11917075
# Pos                0
# Change            -1
# Avail           -826
# Name: 94, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          OrdRes
# DocNum      23035572
# Pos                0
# Change           -10
# Avail           -836
# Name: 95, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          OrdRes
# DocNum      11917075
# Pos                0
# Change            -1
# Avail           -837
# Name: 96, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          OrdRes
# DocNum      23006739
# Pos                0
# Change            -1
# Avail           -838
# Name: 97, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          DepReq
# DocNum       5222561
# Pos                0
# Change           -10
# Avail           -848
# Name: 98, dtype: object
# Partnr        541267
# Date      2018.05.25
# Type          DepReq
# DocNum       5223702
# Pos                0
# Change            -4
# Avail           -852
# Name: 99, dtype: object
# Partnr        541267
# Date      2018.05.28
# Type           Order
# DocNum    2018385382
# Pos           000070
# Change            -1
# Avail           -853
# Name: 100, dtype: object
# Partnr        541267
# Date      2018.05.28
# Type           Order
# DocNum    2018402880
# Pos           000100
# Change            -9
# Avail           -862
# Name: 101, dtype: object
# Partnr        541267
# Date      2018.05.28
# Type          Fr.del
# DocNum    2018451397
# Pos           000020
# Change            -3
# Avail           -865
# Name: 102, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9eb550c44df4> in <module>()
#       4 PD=pd.DataFrame(md04["data"], columns=md04["header"])
#       5 df=PD.iloc[:,0:7]
# ----> 6 total.append(pd.DataFrame(fehaParser(df), columns=header))
#
# <ipython-input-4-56a9a5bca1a7> in fehaParser(df)
#      17         if line[2] == 'Stock' :
#      18             line[5]=line[6]
# ---> 19         if category[line[2]] == 'Receipt' :
#      20             ReceiptQueue.append(line)
#      21         if category[line[2]] == 'Reqmt' :
#
# KeyError: 'Fr.del'

# %%
total
# Out:
# []

# %%
pd.DataFrame(total[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-3e75f2f571b6> in <module>()
# ----> 1 pd.DataFrame(total[0])
#
# IndexError: list index out of range

# %% [markdown]
# ## ACTUAL RUNNING (for MD04list.txt)

# %%
total=[]
filelist=[]
f=open("MD04list.txt","r", encoding="UTF-8")
list=f.readlines()
for i in list :      
    md04=parsingDoc(fileRead(i.replace("\n","")))    
    PD=pd.DataFrame(md04["data"], columns=md04["header"])   
    #PD.plot(x="Date", kind="bar", title=md04['meta'][0])
    df=PD.iloc[:,0:7]    
    total.append(pd.DataFrame(fehaParser(df), columns=header))

# %%
len(total)

# %%
total[0]

# %%
total[1]

# %%
total[2]

# %%
total[3]

# %%
total[4]

# %%
total[5]

# %%
total[6]

# %%
total[7]

# %%
final=pd.DataFrame()
for i in total : 
        final=final.append(i)

# %%
#To save excel file 
writer=pd.ExcelWriter('output.xlsx')
final.to_excel(writer,'Sheet1')
writer.save()
