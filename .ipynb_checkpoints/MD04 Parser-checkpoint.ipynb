# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from md04_func import *

# %%
def orderRead(filename) : 
    document=fileRead(filename)
    partnr=document[5].split("             ")[1].strip()
    orderList=[]
    for line in document[22:-3] : 
        splitLine=line.split("|")
        type=splitLine[3].strip()    

        if (type=='Order') : 
            order= (partnr,splitLine[2].strip(), splitLine[4][:10], int(float(splitLine[7].replace("-",""))), splitLine[10])
            
            
            orderList.append(order)

    return pd.DataFrame(orderList, columns=["partnr", "date", "so","qty","client"] )

# %% [markdown]
# ## UNIT TEST

# %%
filename="529853"
total=[]
filelist=[]
md04=parsingDoc(fileRead(filename))
PD=pd.DataFrame(md04["data"], columns=md04["header"])   
   
df=PD.iloc[:,0:7]        
total.append(pd.DataFrame(fehaParser(df), columns=header))
orderList=orderRead(filename)
final=pd.DataFrame()
for i in total : 
        final=final.append(i)
#To save excel file 
writer=pd.ExcelWriter(filename +"_" +str(datetime.datetime.now().date()) + '_unit_output.xlsx')
final.to_excel(writer,'Sheet1')
orderList.to_excel(writer,'Sheet2')
writer.save()

# %% [markdown]
# ## ACTUAL RUNNING (for MD04list.txt)

# %%
total=[]
filelist=[]
totalOrder=[]
f=open("MD04list.txt","r", encoding="UTF-8")
list=f.readlines()
for i in list :     
    filename=fileRead(i.replace("\n",""))
    md04=parsingDoc(filename)    
    completedKmat=[x + ["","","","",""] for x in md04['data'] if ("CStock" in x and x[-1]>0 )]
    md04['data']=dataWithoutCompletedKmat=[x for x in md04['data'] if  not("CStock" in x and x[-1]>0 )]
    PD=pd.DataFrame(md04["data"], columns=md04["header"])
    orderList=orderRead(i.replace("\n",""))
    #PD.plot(x="Date", kind="bar", title=md04['meta'][0])
    df=PD.iloc[:,0:7]        
    total.append(pd.DataFrame(fehaParser(df), columns=header))
    totalOrder.append(orderList)
# Out:
# Reading the file as raw format 23109748
# plnt number 0360
# Reading the file as raw format 23109748
# both empty
# Reading the file as raw format 23111261
# plnt number 0360
# Reading the file as raw format 23111261
# both empty
# Reading the file as raw format 23121363
# plnt number 0360
# Reading the file as raw format 23121363
# both empty

# %%
type(total)
# Out:
# list

# %% [markdown]
# ## EXCEL FILE

# %%
final=pd.DataFrame()
orderfinal=pd.DataFrame()
for i in total : 
        final=final.append(i)

for i in totalOrder : 
        orderfinal=orderfinal.append(i)

# %%
orderfinal
# Out:
#       partnr        date          so  qty      client
# 0   23109748  2018/07/27  5236303578    1  36016328
# 1   23109748  2018/07/27  5236303579    1  36016328
# 2   23109748  2018/07/27  5236303591    1  36016328
# 3   23109748  2018/07/27  5236303594    1  36016328
# 4   23109748  2018/07/27  5236303595    1  36016328
# 5   23109748  2018/07/27  5236303597    1  36016328
# 6   23109748  2018/07/27  5236303599    1  36016328
# 7   23109748  2018/07/27  5236303600    1  36016328
# 8   23109748  2018/07/27  5236303621    1  36016328
# 9   23109748  2018/07/27  5236303622    1  36016328
# 10  23109748  2018/07/27  5236303623    1  36016328
# 11  23109748  2018/07/27  5236303627    1  36016328
# 12  23109748  2018/07/27  5236303629    1  36016328
# 13  23109748  2018/07/27  5236303641    1  36016328
# 14  23109748  2018/07/27  5236303644    1  36016328
# 15  23109748  2018/07/27  5236303645    1  36016328
# 16  23109748  2018/07/27  5236303647    1  36016328
# ...

# %%
#To save excel file 
writer=pd.ExcelWriter(str(datetime.datetime.now().date()) + '.xlsx')
final.to_excel(writer,'Sheet1')
orderfinal.to_excel(writer, 'Sheet2')
writer.save()
