# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from md04_func import *

# %%
document=fileRead("544038")
md04=parsingDoc(document)
# Out:
# ['544038', '2018/04/16', 'Stock', 0, 0, 2, 0]
# ['544038', '2018/04/17', 'ShipNt', '4045487629', '00001', 9, 1]
# ['544038', '2018/04/17', 'Order', '5236280236', '000010', -15, 0]
# ['544038', '2018/04/17', 'Order', '5236280266', '000230', -4, -1]
# ['544038', '2018/04/20', 'ShipNt', '4045487629', '00001', 1, 0]
# ['544038', '2018/04/24', 'Order', '5236282752', '000160', -1, -1]
# ['544038', '2018/06/04', 'ShipNt', '4045494193', '00001', 3, 0]

# %%
df=pd.DataFrame(md04['data'], columns=md04['header'])
df['cum']=df.Change.cumsum()
df.cum.plot(x="Date")
plt.plot(df.Date, df.cum)
target=df.mask('Type','ShipNt')
plt.plot(target.Date, target.cum)

# %%
filelist=[]
f=open("MD04list.txt","r", encoding="UTF-8")
list=f.readlines()
for i in list :        
    document=fileRead(i.rstrip("\n"))
    md04=parsingDoc(document)
    PD=pd.DataFrame(md04["data"], columns=md04["header"]) 
    
    
    
fig = plt.figure()
ax= PD['Rec/reqd Qty'].plot(x="Date", kind="bar", title=md04['meta'][0])
ax2 = ax.twinx()
ax2.plot(ax.get_xticks(),PD['AvailQty'])
# Out:
# ['543905', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543905', '2018/04/16', 'CStock', '5236280263', '000240', 0, 0]
# ['543905', '2018/07/11', 'ShipNt', '4601952363', '00003', 1, 0]
# ['543906', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543906', '2018/04/16', 'CStock', '5236280263', '000110', 0, 0]
# ['543906', '2018/04/30', 'ShipNt', '4601952363', '00005', 1, 0]
# ['543906', '2018/04/16', 'CStock', '5236281646', '000010', 0, 0]
# ['543906', '2018/07/17', 'ShipNt', '4601956922', '00001', 2, 0]
# ['543906', '2018/04/16', 'CStock', '5236282681', '000140', 0, 0]
# ['543906', '2018/07/18', 'ShipNt', '4601960196', '00002', 1, 0]
# ['543908', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543908', '2018/04/16', 'CStock', '5236280263', '000140', 0, 0]
# ['543908', '2018/04/18', 'ShipNt', '4601952363', '00006', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236280266', '000030', 0, 1]
# ['543908', '2018/04/16', 'CStock', '5236280266', '000050', 0, 0]
# ['543908', '2018/04/18', 'ShipNt', '4601952387', '00003', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236280266', '000240', 0, 1]
# ['543908', '2018/04/16', 'CStock', '5236282640', '000110', 0, 0]
# ['543908', '2018/04/30', 'ShipNt', '4601960171', '00001', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236282681', '000240', 0, 0]
# ['543908', '2018/07/18', 'ShipNt', '4601960196', '00003', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236282681', '000360', 0, 0]
# ['543908', '2018/07/18', 'ShipNt', '4601960196', '00004', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236282681', '000820', 0, 0]
# ['543908', '2018/07/18', 'ShipNt', '4601960196', '00006', 1, 0]
# ['543909', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543909', '2018/04/16', 'CStock', '5236280236', '000080', 0, 0]
# ['543909', '2018/04/17', 'ShipNt', '4601952335', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236280263', '000190', 0, 0]
# ['543909', '2018/04/17', 'ShipNt', '4601952363', '00002', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236280266', '000010', 0, 0]
# ['543909', '2018/04/17', 'ShipNt', '4601952387', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282575', '000260', 0, 0]
# ['543909', '2018/07/18', 'ShipNt', '4601960183', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282575', '000410', 0, 0]
# ['543909', '2018/07/18', 'ShipNt', '4601960183', '00002', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282750', '000120', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960332', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282750', '000410', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960332', '00003', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282752', '000010', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960342', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282752', '000100', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960342', '00002', 1, 0]
# ['543946', '2018/04/16', 'Stock', 0, 0, 0, 10]
# ['543946', '2018/04/16', 'SafeSt', 0, 0, -3, 7]
# ['543946', '2018/04/17', 'Order', '5236280263', '000210', -1, 6]
# ['543946', '2018/04/16', 'StLcSt', 0, 0, 0, 0]
# ['543964', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['543964', '2018/04/16', 'SafeSt', 0, 0, -4, 0]
# ['543964', '2018/04/17', 'Order', '5236280236', '000050', -1, -1]
# ['543964', '2018/04/18', 'ShipNt', '4045481482', '00001', 4, 3]
# ['543964', '2018/06/11', 'PurRqs', '4323661651', '00010 *', 4, 7]
# ['543965', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['543965', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['543965', '2018/04/24', 'Order', '5236282575', '000680', -1, -1]
# ['543965', '2018/04/26', 'ShipNt', '4045481478', '00001', 1, 0]
# ['543965', '2018/05/14', 'PurRqs', '4323663997', '00010 *', 1, 1]
# ['543965', '2018/05/28', 'PurRqs', '4323661131', '00010 *', 1, 2]
# ['543965', '2018/06/11', 'PurRqs', '4323661706', '00010 *', 1, 3]
# ['543965', '2018/06/25', 'PurRqs', '4323666815', '00010 *', 1, 4]
# ['543965', '2018/07/16', 'PurRqs', '4323670933', '00010 *', 1, 5]
# ['543965', '2018/07/30', 'PurRqs', '4323669485', '00010 *', 1, 6]
# ['543966', '2018/04/16', 'Stock', 0, 0, 0, 3]
# ['543966', '2018/04/16', 'SafeSt', 0, 0, -2, 1]
# ['543966', '2018/04/17', 'Order', '5236280236', '000030', -1, 0]
# ['543966', '2018/04/17', 'Order', '5236280263', '000270', -1, -1]
# ['543966', '2018/04/24', 'Order', '5236282575', '000380', -1, -2]
# ['543966', '2018/04/24', 'Order', '5236282752', '000070', -1, -3]
# ['543966', '2018/04/26', 'SchLne', '4045495588', '00001', 2, -1]
# ['543966', '2018/06/08', 'ShipNt', '4045481473', '00001', 1, 0]
# ['543966', '2018/06/08', 'ShipNt', '4045487818', '00001', 2, 2]
# ['543966', '2018/06/08', 'ShipNt', '4045492873', '00001', 1, 3]
# ['543988', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['543988', '2018/04/16', 'SafeSt', 0, 0, -3, 1]
# ['543988', '2018/04/17', 'Order', '5236280263', '000230', -1, 0]
# ['543988', '2018/04/18', 'Order', '5236282601', '000010', -4, -4]
# ['543988', '2018/04/23', 'ShipNt', '4045492893', '00001', 4, 0]
# ['543988', '2018/05/14', 'PurRqs', '4323663663', '00010 *', 4, 4]
# ['543988', '2018/07/16', 'PurRqs', '4323670818', '00010 *', 4, 8]
# ['543989', '2018/04/16', 'Stock', 0, 0, 0, 16]
# ['543989', '2018/04/16', 'SafeSt', 0, 0, -2, 14]
# ['543989', '2018/04/24', 'Order', '5236282575', '000500', -1, 13]
# ['543989', '2018/04/24', 'Order', '5236282575', '000770', -1, 12]
# ['543990', '2018/04/16', 'Stock', 0, 0, 0, 5]
# ['543990', '2018/04/16', 'SafeSt', 0, 0, -3, 2]
# ['543990', '2018/04/13', 'ShipNt', '4045467038', '00001', 3, 5]
# ['543990', '2018/04/16', 'Deliv.', '5436673176', '000010', -1, 4]
# ['543990', '2018/04/17', 'Order', '5236280236', '000103', -1, 3]
# ['543990', '2018/04/17', 'Order', '5236280246', '000020', -1, 2]
# ['543990', '2018/04/17', 'Order', '5236280246', '000030', -1, 1]
# ['543990', '2018/05/14', 'PurRqs', '4323663922', '00010 *', 3, 4]
# ['543990', '2018/05/14', 'Order', '5236283485', '000090', -6, -2]
# ['543990', '2018/06/04', 'PurRqs', '4323669033', '00010 *', 3, 1]
# ['543990', '2018/06/25', 'PurRqs', '4323666119', '00010 *', 3, 4]
# ['543990', '2018/07/23', 'PurRqs', '4323663841', '00010 *', 3, 7]
# ['544011', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['544011', '2018/04/16', 'SafeSt', 0, 0, -3, 1]
# ['544011', '2018/04/17', 'Order', '5236280263', '000160', -1, 0]
# ['544011', '2018/04/24', 'Order', '5236282681', '000300', -1, -1]
# ['544011', '2018/04/24', 'Order', '5236282681', '000610', -1, -2]
# ['544011', '2018/04/26', 'PurRqs', '4323663161', '00010 *', 3, 1]
# ['544011', '2018/05/04', 'ShipNt', '4045493433', '00001', 3, 4]
# ['544011', '2018/07/16', 'PurRqs', '4323670186', '00010 *', 3, 7]
# ['544012', '2018/04/16', 'Stock', 0, 0, 0, 5]
# ['544012', '2018/04/16', 'SafeSt', 0, 0, -3, 2]
# ['544012', '2018/04/17', 'Order', '5236280263', '000100', -1, 1]
# ['544012', '2018/04/24', 'Order', '5236282681', '000110', -1, 0]
# ['544012', '2018/04/24', 'Order', '5236282681', '000210', -1, -1]
# ['544012', '2018/04/26', 'PurRqs', '4323663645', '00010 *', 3, 2]
# ['544012', '2018/05/10', 'ShipNt', '4045493434', '00001', 3, 5]
# ['544012', '2018/05/14', 'Order', '5236283485', '000030', -1, 4]
# ['544012', '2018/07/30', 'PurRqs', '4323669990', '00010 *', 3, 7]
# ['544013', '2018/04/16', 'Stock', 0, 0, 0, 5]
# ['544013', '2018/04/16', 'SafeSt', 0, 0, -2, 3]
# ['544013', '2018/04/16', 'Deliv.', '5436672884', '000070', -1, 2]
# ['544013', '2018/04/17', 'Order', '5236280263', '000130', -1, 1]
# ['544013', '2018/06/25', 'PurRqs', '4323666487', '00010 *', 2, 3]
# ['544025', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['544025', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['544025', '2018/04/18', 'ShipNt', '4045481475', '00001', 1, 1]
# ['544025', '2018/04/18', 'ShipNt', '4045482400', '00001', 2, 3]
# ['544025', '2018/04/18', 'ShipNt', '4045487817', '00001', 2, 5]
# ['544025', '2018/04/24', 'Order', '5236282758', '000670', -1, 4]
# ['544025', '2018/04/24', 'Order', '5236282758', '000920', -1, 3]
# ['544025', '2018/04/24', 'Order', '5236282758', '001170', -1, 2]
# ['544025', '2018/05/28', 'PurRqs', '4323661025', '00010 *', 1, 3]
# ['544025', '2018/06/11', 'PurRqs', '4323661195', '00010 *', 1, 4]
# ['544025', '2018/06/25', 'PurRqs', '4323666978', '00010 *', 1, 5]
# ['544025', '2018/07/16', 'PurRqs', '4323670594', '00010 *', 1, 6]
# ['544025', '2018/07/30', 'PurRqs', '4323670514', '00010 *', 1, 7]
# ['544027', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['544027', '2018/04/16', 'SafeSt', 0, 0, -3, 1]
# ['544027', '2018/04/23', 'SchLne', '4045493418', '00001', 9, 10]
# ['544027', '2018/04/23', 'SchLne', '4045493436', '00001', 3, 13]
# ['544027', '2018/04/24', 'Order', '5236282714', '000380', -2, 11]
# ['544027', '2018/04/24', 'Order', '5236282714', '000410', -2, 9]
# ['544027', '2018/04/24', 'Order', '5236282714', '000600', -2, 7]
# ['544027', '2018/04/24', 'Order', '5236282753', '000200', -2, 5]
# ['544027', '2018/04/24', 'Order', '5236282753', '000390', -2, 3]
# ['544027', '2018/04/24', 'Order', '5236282758', '000790', -1, 2]
# ['544028', '2018/04/16', 'Stock', 0, 0, 0, 13]
# ['544028', '2018/04/16', 'SafeSt', 0, 0, -5, 8]
# ['544028', '2017/09/21', 'ShipNt', '4045256616', '00010', 17, 25]
# ['544028', '2018/04/24', 'Order', '5236282714', '000260', -2, 23]
# ['544028', '2018/04/24', 'Order', '5236282714', '000320', -2, 21]
# ['544036', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['544036', '2018/04/17', 'Order', '5236280236', '000070', -1, -1]
# ['544036', '2018/04/18', 'ShipNt', '4045487628', '00001', 1, 0]
# ['544036', '2018/04/24', 'ShipNt', '4045494191', '00001', 1, 1]
# ['544036', '2018/04/24', 'Order', '5236282575', '000740', -1, 0]
# ['544037', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['544037', '2018/04/24', 'Order', '5236282681', '000520', -1, -1]
# ['544037', '2018/07/06', 'ShipNt', '4045494192', '00001', 1, 0]
# ['544038', '2018/04/16', 'Stock', 0, 0, 2, 0]
# ['544038', '2018/04/17', 'ShipNt', '4045487629', '00001', 9, 1]
# ['544038', '2018/04/17', 'Order', '5236280236', '000010', -15, 0]
# ['544038', '2018/04/17', 'Order', '5236280266', '000230', -4, -1]
# ['544038', '2018/04/20', 'ShipNt', '4045487629', '00001', 1, 0]
# ['544038', '2018/04/24', 'Order', '5236282752', '000160', -1, -1]
# ['544038', '2018/06/04', 'ShipNt', '4045494193', '00001', 3, 0]
# ['544049', '2018/04/16', 'Stock', 0, 0, 0, 3]
# ['544049', '2018/04/24', 'SchLne', '4045494194', '00001', 4, 7]
# ['544049', '2018/04/24', 'Order', '5236282714', '000660', -2, 5]
# ['544049', '2018/04/24', 'Order', '5236282753', '000450', -2, 3]
# ['544049', '2018/04/24', 'Order', '5236282758', '000070', -1, 2]
# ['544049', '2018/04/24', 'Order', '5236282758', '000130', -1, 1]
# ['544049', '2018/04/24', 'Order', '5236282758', '000190', -1, 0]
# ['544052', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['544052', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['544052', '2018/04/23', 'SchLne', '4045493437', '00001', 2, 2]
# ['544052', '2018/04/24', 'Order', '5236282758', '000730', -1, 1]
# ['544052', '2018/06/25', 'PurRqs', '4323666578', '00010 *', 2, 3]
# ['544053', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['544053', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['544053', '2018/04/24', 'Order', '5236282758', '000540', -1, -1]
# ['544053', '2018/04/24', 'Order', '5236282758', '000760', -1, -2]
# ['544053', '2018/04/24', 'Order', '5236282722', '000890', -1, -3]
# ['544053', '2018/04/24', 'Order', '5236282733', '001050', -1, -4]
# ['544053', '2018/04/24', 'Order', '5236282711', '001280', -1, -5]
# ['544053', '2018/04/26', 'Order', '5236282777', '001280', -1, -5]
# ['544053', '2018/04/27', 'Order', '5236282711', '001280', -1, -5]
# ['544053', '2018/04/29', 'PurRqs', '4323666650', '00010 *', 3, -2]
# ['544053', '2018/04/30', 'PurRqs', '4323669492', '00010 *', 2, 0]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\dev\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rec/reqd Qty'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-407-7758a8a96672> in <module>()
#      10
#      11 fig = plt.figure()
# ---> 12 ax= PD['Rec/reqd Qty'].plot(x="Date", kind="bar", title=md04['meta'][0])
#      13 ax2 = ax.twinx()
#      14 ax2.plot(ax.get_xticks(),PD['AvailQty'])
#
# C:\dev\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\dev\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\dev\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\dev\anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\dev\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rec/reqd Qty'

# %%
md04=parsingDoc(fileRead("544012"))
PD=pd.DataFrame(md04["data"], columns=md04["header"])   
#PD.plot(x="Date", kind="bar", title=md04['meta'][0])
df=PD.iloc[:,0:6]
# Out:
# ['544012', '2018/04/16', 'Stock', 0, 0, 0, 5]
# ['544012', '2018/04/16', 'SafeSt', 0, 0, -3, 2]
# ['544012', '2018/04/17', 'Order', '5236280263', '000100', -1, 1]
# ['544012', '2018/04/24', 'Order', '5236282681', '000110', -1, 0]
# ['544012', '2018/04/24', 'Order', '5236282681', '000210', -1, -1]
# ['544012', '2018/04/26', 'PurRqs', '4323663645', '00010 *', 3, 2]
# ['544012', '2018/05/10', 'ShipNt', '4045493434', '00001', 3, 5]
# ['544012', '2018/05/14', 'Order', '5236283485', '000030', -1, 4]
# ['544012', '2018/07/30', 'PurRqs', '4323669990', '00010 *', 3, 7]

# %%
category = {
    'ShipNt':"Receipt",
    'SchLne':"Recceipt",
    'Order' : 'Reqmt',
    'Stock' : 'Receipt',
    'CStock' : '',
    'Ordres' : 'Reqmt',
    'SafeSt' : '',
    'StLcSt' : '',
    'PurRqs' : '',
    'Deliv.' : 'Reqmt'
}

# %%
ReceiptQueue = []
ReqmtQueue=[]
MappedResult=[]
flag=0
for index, line in df.iterrows() :    
    if line[5]==0 : continue
    if category[line[2]] == 'Receipt' :        
        ReceiptQueue.append(line)
    if category[line[2]] == 'Reqmt' :
        ReqmtQueue.append(line)
    else :
        continue

# %%
ReqmtQueue
# Out:
# [Partnr        544012
#  Date      2018/04/17
#  Type           Order
#  DocNum    5236280263
#  Pos           000100
#  Change            -1
#  Name: 2, dtype: object, Partnr        544012
#  Date      2018/04/24
#  Type           Order
#  DocNum    5236282681
#  Pos           000110
#  Change            -1
#  Name: 3, dtype: object, Partnr        544012
#  Date      2018/04/24
#  Type           Order
#  DocNum    5236282681
#  Pos           000210
#  Change            -1
#  Name: 4, dtype: object, Partnr        544012
#  Date      2018/05/14
#  Type           Order
#  DocNum    5236283485
#  Pos           000030
#  Change            -1
#  Name: 7, dtype: object]

# %%
while True : 
    try :
        Receipt = ReceiptQueue.pop(0)
        Reqmt = ReqmtQueue.pop(0)  
        print (Receipt[5], Reqmt[5])
        if Receipt[5] + Reqmt[5] == 0 :
            print("==")
            flag=0
            MappedResult.append([Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])    
            Receipt = ReceiptQueue.pop(0)
            Reqmt = ReqmtQueue.pop(0)  

        if Receipt[5] + Reqmt[5] > 0 :       
            print("Receipt> Reqmt")
            flag=1
            MappedResult.append([Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Reqmt[5]])    
            Receipt[5] +=Reqmt[5]
            Reqmt = ReqmtQueue.pop(0)  

        if Receipt[5] + Reqmt[5] < 0 :            
            print("Receipt <  Reqmt")
            flag=-1
            MappedResult.append([Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Receipt[5],  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])
            Reqmt[5] +=Receipt[5]
            Receipt = ReceiptQueue.pop(0)

    except Exception as e:   

        print(e)
        print ("flag:", flag)
        if flag == 1:
                MappedResult.append([Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],'','' ,'' ,'' ,'' ]) 
        elif flag == -1:
                MappedResult.append(['','','','','',  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])          

        print("ReqmtQueue :", len(ReqmtQueue), "ReceiptQueue :", len(ReceiptQueue))
        for Reqmt in ReqmtQueue :
            MappedResult.append([Reqmt[1], Reqmt[2], Reqmt[3], Reqmt[4], Reqmt[5],'','' ,'' ,'' ,'' ]) 

        for Receipt in ReceiptQueue :
            MappedResult.append(['','','','','',  Receipt[1], Receipt[2], Receipt[3], Receipt[4], Receipt[5]])          

        break
# Out:
# 3 -1
# Receipt> Reqmt
# pop from empty list
# flag: 1
# ReqmtQueue : 2 ReceiptQueue : 0

# %%
pd.DataFrame(MappedResult)
# Out:
#             0      1           2       3  4           5       6           7  \
# 0  2018/04/17  Order  5236280263  000100 -1  2018/05/10  ShipNt  4045493434
# 1  2018/04/24  Order  5236282681  000110 -1
# 2  2018/04/24  Order  5236282681  000210 -1
# 3  2018/05/14  Order  5236283485  000030 -1
#
#        8   9
# 0  00001  -1
# 1
# 2
# 3

# %%
df
# Out:
#    Partnr        Date    Type      DocNum      Pos  Change
# 0  544012  2018/04/16   Stock           0        0       0
# 1  544012  2018/04/16  SafeSt           0        0      -3
# 2  544012  2018/04/17   Order  5236280263   000100      -1
# 3  544012  2018/04/24   Order  5236282681   000110      -1
# 4  544012  2018/04/24   Order  5236282681   000210      -1
# 5  544012  2018/04/26  PurRqs  4323663645  00010 *       3
# 6  544012  2018/05/10  ShipNt  4045493434    00001       3
# 7  544012  2018/05/14   Order  5236283485   000030      -1
# 8  544012  2018/07/30  PurRqs  4323669990  00010 *       3

# %%
filelist=[]
f=open("MD04list.txt","r", encoding="UTF-8")
list=f.readlines()
for i in list :  
    print(i.replace("\n",""))
    md04=parsingDoc(fileRead(i.replace("\n","")))    
    PD=pd.DataFrame(md04["data"], columns=md04["header"])   
    #PD.plot(x="Date", kind="bar", title=md04['meta'][0])
    df=PD.iloc[:,0:6]
    a=pd.DataFrame(fehaParser(df))
# Out:
# 543905
# ['543905', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543905', '2018/04/16', 'CStock', '5236280263', '000240', 0, 0]
# ['543905', '2018/07/11', 'ShipNt', '4601952363', '00003', 1, 0]
# pop from empty list
# flag: 0
# ReqmtQueue : 0 ReceiptQueue : 1
# 543906
# ['543906', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543906', '2018/04/16', 'CStock', '5236280263', '000110', 0, 0]
# ['543906', '2018/04/30', 'ShipNt', '4601952363', '00005', 1, 0]
# ['543906', '2018/04/16', 'CStock', '5236281646', '000010', 0, 0]
# ['543906', '2018/07/17', 'ShipNt', '4601956922', '00001', 2, 0]
# ['543906', '2018/04/16', 'CStock', '5236282681', '000140', 0, 0]
# ['543906', '2018/07/18', 'ShipNt', '4601960196', '00002', 1, 0]
# pop from empty list
# flag: 0
# ReqmtQueue : 0 ReceiptQueue : 3
# 543908
# ['543908', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543908', '2018/04/16', 'CStock', '5236280263', '000140', 0, 0]
# ['543908', '2018/04/18', 'ShipNt', '4601952363', '00006', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236280266', '000030', 0, 1]
# ['543908', '2018/04/16', 'CStock', '5236280266', '000050', 0, 0]
# ['543908', '2018/04/18', 'ShipNt', '4601952387', '00003', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236280266', '000240', 0, 1]
# ['543908', '2018/04/16', 'CStock', '5236282640', '000110', 0, 0]
# ['543908', '2018/04/30', 'ShipNt', '4601960171', '00001', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236282681', '000240', 0, 0]
# ['543908', '2018/07/18', 'ShipNt', '4601960196', '00003', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236282681', '000360', 0, 0]
# ['543908', '2018/07/18', 'ShipNt', '4601960196', '00004', 1, 0]
# ['543908', '2018/04/16', 'CStock', '5236282681', '000820', 0, 0]
# ['543908', '2018/07/18', 'ShipNt', '4601960196', '00006', 1, 0]
# pop from empty list
# flag: 0
# ReqmtQueue : 0 ReceiptQueue : 6
# 543909
# ['543909', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['543909', '2018/04/16', 'CStock', '5236280236', '000080', 0, 0]
# ['543909', '2018/04/17', 'ShipNt', '4601952335', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236280263', '000190', 0, 0]
# ['543909', '2018/04/17', 'ShipNt', '4601952363', '00002', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236280266', '000010', 0, 0]
# ['543909', '2018/04/17', 'ShipNt', '4601952387', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282575', '000260', 0, 0]
# ['543909', '2018/07/18', 'ShipNt', '4601960183', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282575', '000410', 0, 0]
# ['543909', '2018/07/18', 'ShipNt', '4601960183', '00002', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282750', '000120', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960332', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282750', '000410', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960332', '00003', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282752', '000010', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960342', '00001', 1, 0]
# ['543909', '2018/04/16', 'CStock', '5236282752', '000100', 0, 0]
# ['543909', '2018/07/19', 'ShipNt', '4601960342', '00002', 1, 0]
# pop from empty list
# flag: 0
# ReqmtQueue : 0 ReceiptQueue : 9
# 543946
# ['543946', '2018/04/16', 'Stock', 0, 0, 0, 10]
# ['543946', '2018/04/16', 'SafeSt', 0, 0, -3, 7]
# ['543946', '2018/04/17', 'Order', '5236280263', '000210', -1, 6]
# ['543946', '2018/04/16', 'StLcSt', 0, 0, 0, 0]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 0 ReceiptQueue : 0
# 543964
# ['543964', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['543964', '2018/04/16', 'SafeSt', 0, 0, -4, 0]
# ['543964', '2018/04/17', 'Order', '5236280236', '000050', -1, -1]
# ['543964', '2018/04/18', 'ShipNt', '4045481482', '00001', 4, 3]
# ['543964', '2018/06/11', 'PurRqs', '4323661651', '00010 *', 4, 7]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 0 ReceiptQueue : 0
# 543965
# ['543965', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['543965', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['543965', '2018/04/24', 'Order', '5236282575', '000680', -1, -1]
# ['543965', '2018/04/26', 'ShipNt', '4045481478', '00001', 1, 0]
# ['543965', '2018/05/14', 'PurRqs', '4323663997', '00010 *', 1, 1]
# ['543965', '2018/05/28', 'PurRqs', '4323661131', '00010 *', 1, 2]
# ['543965', '2018/06/11', 'PurRqs', '4323661706', '00010 *', 1, 3]
# ['543965', '2018/06/25', 'PurRqs', '4323666815', '00010 *', 1, 4]
# ['543965', '2018/07/16', 'PurRqs', '4323670933', '00010 *', 1, 5]
# ['543965', '2018/07/30', 'PurRqs', '4323669485', '00010 *', 1, 6]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 0 ReceiptQueue : 0
# 543966
# ['543966', '2018/04/16', 'Stock', 0, 0, 0, 3]
# ['543966', '2018/04/16', 'SafeSt', 0, 0, -2, 1]
# ['543966', '2018/04/17', 'Order', '5236280236', '000030', -1, 0]
# ['543966', '2018/04/17', 'Order', '5236280263', '000270', -1, -1]
# ['543966', '2018/04/24', 'Order', '5236282575', '000380', -1, -2]
# ['543966', '2018/04/24', 'Order', '5236282752', '000070', -1, -3]
# ['543966', '2018/04/26', 'SchLne', '4045495588', '00001', 2, -1]
# ['543966', '2018/06/08', 'ShipNt', '4045481473', '00001', 1, 0]
# ['543966', '2018/06/08', 'ShipNt', '4045487818', '00001', 2, 2]
# ['543966', '2018/06/08', 'ShipNt', '4045492873', '00001', 1, 3]
# 0 -1
# Receipt <  Reqmt
# 2 -1
# Receipt> Reqmt
# 1 -1
# ==
# pop from empty list
# flag: 0
# ReqmtQueue : 0 ReceiptQueue : 0
# 543988
# ['543988', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['543988', '2018/04/16', 'SafeSt', 0, 0, -3, 1]
# ['543988', '2018/04/17', 'Order', '5236280263', '000230', -1, 0]
# ['543988', '2018/04/18', 'Order', '5236282601', '000010', -4, -4]
# ['543988', '2018/04/23', 'ShipNt', '4045492893', '00001', 4, 0]
# ['543988', '2018/05/14', 'PurRqs', '4323663663', '00010 *', 4, 4]
# ['543988', '2018/07/16', 'PurRqs', '4323670818', '00010 *', 4, 8]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 1 ReceiptQueue : 0
# 543989
# ['543989', '2018/04/16', 'Stock', 0, 0, 0, 16]
# ['543989', '2018/04/16', 'SafeSt', 0, 0, -2, 14]
# ['543989', '2018/04/24', 'Order', '5236282575', '000500', -1, 13]
# ['543989', '2018/04/24', 'Order', '5236282575', '000770', -1, 12]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 1 ReceiptQueue : 0
# 543990
# ['543990', '2018/04/16', 'Stock', 0, 0, 0, 5]
# ['543990', '2018/04/16', 'SafeSt', 0, 0, -3, 2]
# ['543990', '2018/04/13', 'ShipNt', '4045467038', '00001', 3, 5]
# ['543990', '2018/04/16', 'Deliv.', '5436673176', '000010', -1, 4]
# ['543990', '2018/04/17', 'Order', '5236280236', '000103', -1, 3]
# ['543990', '2018/04/17', 'Order', '5236280246', '000020', -1, 2]
# ['543990', '2018/04/17', 'Order', '5236280246', '000030', -1, 1]
# ['543990', '2018/05/14', 'PurRqs', '4323663922', '00010 *', 3, 4]
# ['543990', '2018/05/14', 'Order', '5236283485', '000090', -6, -2]
# ['543990', '2018/06/04', 'PurRqs', '4323669033', '00010 *', 3, 1]
# ['543990', '2018/06/25', 'PurRqs', '4323666119', '00010 *', 3, 4]
# ['543990', '2018/07/23', 'PurRqs', '4323663841', '00010 *', 3, 7]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 4 ReceiptQueue : 0
# 544011
# ['544011', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['544011', '2018/04/16', 'SafeSt', 0, 0, -3, 1]
# ['544011', '2018/04/17', 'Order', '5236280263', '000160', -1, 0]
# ['544011', '2018/04/24', 'Order', '5236282681', '000300', -1, -1]
# ['544011', '2018/04/24', 'Order', '5236282681', '000610', -1, -2]
# ['544011', '2018/04/26', 'PurRqs', '4323663161', '00010 *', 3, 1]
# ['544011', '2018/05/04', 'ShipNt', '4045493433', '00001', 3, 4]
# ['544011', '2018/07/16', 'PurRqs', '4323670186', '00010 *', 3, 7]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 2 ReceiptQueue : 0
# 544012
# ['544012', '2018/04/16', 'Stock', 0, 0, 0, 5]
# ['544012', '2018/04/16', 'SafeSt', 0, 0, -3, 2]
# ['544012', '2018/04/17', 'Order', '5236280263', '000100', -1, 1]
# ['544012', '2018/04/24', 'Order', '5236282681', '000110', -1, 0]
# ['544012', '2018/04/24', 'Order', '5236282681', '000210', -1, -1]
# ['544012', '2018/04/26', 'PurRqs', '4323663645', '00010 *', 3, 2]
# ['544012', '2018/05/10', 'ShipNt', '4045493434', '00001', 3, 5]
# ['544012', '2018/05/14', 'Order', '5236283485', '000030', -1, 4]
# ['544012', '2018/07/30', 'PurRqs', '4323669990', '00010 *', 3, 7]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 3 ReceiptQueue : 0
# 544013
# ['544013', '2018/04/16', 'Stock', 0, 0, 0, 5]
# ['544013', '2018/04/16', 'SafeSt', 0, 0, -2, 3]
# ['544013', '2018/04/16', 'Deliv.', '5436672884', '000070', -1, 2]
# ['544013', '2018/04/17', 'Order', '5236280263', '000130', -1, 1]
# ['544013', '2018/06/25', 'PurRqs', '4323666487', '00010 *', 2, 3]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 1 ReceiptQueue : 0
# 544025
# ['544025', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['544025', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['544025', '2018/04/18', 'ShipNt', '4045481475', '00001', 1, 1]
# ['544025', '2018/04/18', 'ShipNt', '4045482400', '00001', 2, 3]
# ['544025', '2018/04/18', 'ShipNt', '4045487817', '00001', 2, 5]
# ['544025', '2018/04/24', 'Order', '5236282758', '000670', -1, 4]
# ['544025', '2018/04/24', 'Order', '5236282758', '000920', -1, 3]
# ['544025', '2018/04/24', 'Order', '5236282758', '001170', -1, 2]
# ['544025', '2018/05/28', 'PurRqs', '4323661025', '00010 *', 1, 3]
# ['544025', '2018/06/11', 'PurRqs', '4323661195', '00010 *', 1, 4]
# ['544025', '2018/06/25', 'PurRqs', '4323666978', '00010 *', 1, 5]
# ['544025', '2018/07/16', 'PurRqs', '4323670594', '00010 *', 1, 6]
# ['544025', '2018/07/30', 'PurRqs', '4323670514', '00010 *', 1, 7]
# 0 -1
# Receipt <  Reqmt
# 2 -1
# Receipt> Reqmt
# pop from empty list
# flag: 1
# ReqmtQueue : 0 ReceiptQueue : 0
# 544027
# ['544027', '2018/04/16', 'Stock', 0, 0, 0, 4]
# ['544027', '2018/04/16', 'SafeSt', 0, 0, -3, 1]
# ['544027', '2018/04/23', 'SchLne', '4045493418', '00001', 9, 10]
# ['544027', '2018/04/23', 'SchLne', '4045493436', '00001', 3, 13]
# ['544027', '2018/04/24', 'Order', '5236282714', '000380', -2, 11]
# ['544027', '2018/04/24', 'Order', '5236282714', '000410', -2, 9]
# ['544027', '2018/04/24', 'Order', '5236282714', '000600', -2, 7]
# ['544027', '2018/04/24', 'Order', '5236282753', '000200', -2, 5]
# ['544027', '2018/04/24', 'Order', '5236282753', '000390', -2, 3]
# ['544027', '2018/04/24', 'Order', '5236282758', '000790', -1, 2]
# 0 -2
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 5 ReceiptQueue : 0
# 544028
# ['544028', '2018/04/16', 'Stock', 0, 0, 0, 13]
# ['544028', '2018/04/16', 'SafeSt', 0, 0, -5, 8]
# ['544028', '2017/09/21', 'ShipNt', '4045256616', '00010', 17, 25]
# ['544028', '2018/04/24', 'Order', '5236282714', '000260', -2, 23]
# ['544028', '2018/04/24', 'Order', '5236282714', '000320', -2, 21]
# 0 -2
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 1 ReceiptQueue : 0
# 544036
# ['544036', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['544036', '2018/04/17', 'Order', '5236280236', '000070', -1, -1]
# ['544036', '2018/04/18', 'ShipNt', '4045487628', '00001', 1, 0]
# ['544036', '2018/04/24', 'ShipNt', '4045494191', '00001', 1, 1]
# ['544036', '2018/04/24', 'Order', '5236282575', '000740', -1, 0]
# 0 -1
# Receipt <  Reqmt
# 1 -1
# ==
# pop from empty list
# flag: 0
# ReqmtQueue : 0 ReceiptQueue : 0
# 544037
# ['544037', '2018/04/16', 'Stock', 0, 0, 0, 0]
# ['544037', '2018/04/24', 'Order', '5236282681', '000520', -1, -1]
# ['544037', '2018/07/06', 'ShipNt', '4045494192', '00001', 1, 0]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 0 ReceiptQueue : 0
# 544038
# ['544038', '2018/04/16', 'Stock', 0, 0, 2, 0]
# ['544038', '2018/04/17', 'ShipNt', '4045487629', '00001', 9, 1]
# ['544038', '2018/04/17', 'Order', '5236280236', '000010', -15, 0]
# ['544038', '2018/04/17', 'Order', '5236280266', '000230', -4, -1]
# ['544038', '2018/04/20', 'ShipNt', '4045487629', '00001', 1, 0]
# ['544038', '2018/04/24', 'Order', '5236282752', '000160', -1, -1]
# ['544038', '2018/06/04', 'ShipNt', '4045494193', '00001', 3, 0]
# 2 -15
# Receipt <  Reqmt
# 1 -4
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 1 ReceiptQueue : 0
# 544049
# ['544049', '2018/04/16', 'Stock', 0, 0, 0, 3]
# ['544049', '2018/04/24', 'SchLne', '4045494194', '00001', 4, 7]
# ['544049', '2018/04/24', 'Order', '5236282714', '000660', -2, 5]
# ['544049', '2018/04/24', 'Order', '5236282753', '000450', -2, 3]
# ['544049', '2018/04/24', 'Order', '5236282758', '000070', -1, 2]
# ['544049', '2018/04/24', 'Order', '5236282758', '000130', -1, 1]
# ['544049', '2018/04/24', 'Order', '5236282758', '000190', -1, 0]
# 0 -2
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 4 ReceiptQueue : 0
# 544052
# ['544052', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['544052', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['544052', '2018/04/23', 'SchLne', '4045493437', '00001', 2, 2]
# ['544052', '2018/04/24', 'Order', '5236282758', '000730', -1, 1]
# ['544052', '2018/06/25', 'PurRqs', '4323666578', '00010 *', 2, 3]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 0 ReceiptQueue : 0
# 544053
# ['544053', '2018/04/16', 'Stock', 0, 0, 0, 2]
# ['544053', '2018/04/16', 'SafeSt', 0, 0, -2, 0]
# ['544053', '2018/04/24', 'Order', '5236282758', '000540', -1, -1]
# ['544053', '2018/04/24', 'Order', '5236282758', '000760', -1, -2]
# ['544053', '2018/04/24', 'Order', '5236282722', '000890', -1, -3]
# ['544053', '2018/04/24', 'Order', '5236282733', '001050', -1, -4]
# ['544053', '2018/04/24', 'Order', '5236282711', '001280', -1, -5]
# ['544053', '2018/04/26', 'Order', '5236282777', '001280', -1, -5]
# ['544053', '2018/04/27', 'Order', '5236282711', '001280', -1, -5]
# ['544053', '2018/04/29', 'PurRqs', '4323666650', '00010 *', 3, -2]
# ['544053', '2018/04/30', 'PurRqs', '4323669492', '00010 *', 2, 0]
# 0 -1
# Receipt <  Reqmt
# pop from empty list
# flag: -1
# ReqmtQueue : 6 ReceiptQueue : 0
